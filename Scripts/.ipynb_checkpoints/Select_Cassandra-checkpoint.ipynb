# %% [markdown]
# Script de select datos Cassandra en cluster multidomain

# %%
# !pip install mysql-connector==2.1.7
# !pip install pandas
# !pip install sqlalchemy
#requiere instalación adicional, consultar https://github.com/PyMySQL/mysqlclient
# !pip install mysqlclient
# !pip install numpy
# !pip install pymysql
# Out:
# Requirement already satisfied: mysql-connector==2.1.7 in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (2.1.7)
# Requirement already satisfied: pandas in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (from pandas) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Requirement already satisfied: sqlalchemy in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (1.3.13)
# Requirement already satisfied: mysqlclient in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: numpy in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (1.18.1)
# Requirement already satisfied: pymysql in /home/danielherranzsegundo/anaconda3/lib/python3.7/site-packages (1.0.2)

# %%
import pandas as pd
import numpy as np
import os
import json
import random
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import time
from pprint import pprint
import psutil
import uuid
from cassandra.query import tuple_factory
from cassandra.query import dict_factory
from cassandra.query import BatchStatement, SimpleStatement
from cassandra.policies import RetryPolicy

# %%
#Los resultados de medidas de tiempo en carga por dominios se almacenan en estos objetos.
#Se itera durante 100 iteraciones para sacar medias
#repeticiones
repeats = 100

# %%
#Ficheros de salida
resultados_etl_select = '../Results/Cassandra/CassandraSelect_test_{}.csv'

# %%
def save_results_to_csv(results,file):
    #Guardamos los resultados en csv
    from datetime import datetime
    
    csv_df = pd.DataFrame(results, columns=['Registros', 'Tiempo', 'CPU','Memoria'])
    dia = datetime.now().strftime("%d%m%Y_%H_%M_%S")
    csv_df.to_csv(file.format(str(dia)))

# %%
from cassandra.cluster import Cluster, ExecutionProfile, EXEC_PROFILE_DEFAULT
from cassandra.policies import WhiteListRoundRobinPolicy, DowngradingConsistencyRetryPolicy
from cassandra.query import tuple_factory
from cassandra import ConsistencyLevel

profile = ExecutionProfile(
    load_balancing_policy=WhiteListRoundRobinPolicy(['127.0.0.1']),
    retry_policy=DowngradingConsistencyRetryPolicy(),
    consistency_level=ConsistencyLevel.ALL,
    serial_consistency_level=ConsistencyLevel.LOCAL_SERIAL,
    request_timeout=3600,
    row_factory=tuple_factory
)
cluster = Cluster(execution_profiles={EXEC_PROFILE_DEFAULT: profile})
session = cluster.connect()
print(session.execute("SELECT release_version FROM system.local").one())

session.execute('USE currentaccountkeyspace')

rows = session.execute('SELECT count(*) FROM currentaccount')

for row in rows:
    print(row)
# Out:
# ('4.0.3',)
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-80-e6acbc510c6b> in <module>
#      18 session.execute('USE currentaccountkeyspace')
#      19
# ---> 20 rows = session.execute('SELECT count(*) FROM currentaccount')
#      21
#      22 for row in rows:
#
# ~/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.Session.execute()
#
# ~/anaconda3/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.ResponseFuture.result()
#
# ReadTimeout: Error from server: code=1200 [Coordinator node timed out waiting for replica nodes' responses] message="Operation timed out - received only 0 responses." info={'consistency': 'ALL', 'required_responses': 2, 'received_responses': 0}

# %% [markdown]
# # Select test multidomain

# %%
#Obtenemos los posibles valores de pais. Se iterará por ellos para cambiar en bucle los registros
session.execute('USE customerprofilekeyspace')
result = session.execute("""SELECT PartyId FROM customerprofilekeyspace.customerprofile limit 1000;""")
partyId_list= []
for partyId in result:
    partyId_list.append(partyId[0])
print(len(partyId_list))
# Out:
# 1000

# %%
random.choice(partyId_list)
# Out:
# '5437cec2-bf62-11ec-b68e-3bdfc8280f2e'

# %%
from cassandra import ConsistencyLevel
from cassandra.query import SimpleStatement
from cassandra import concurrent

registers = []
batch = BatchStatement(consistency_level=ConsistencyLevel.ALL)
account_id_list = []

#Cargas Masiva con Many
def selectCollectionCustomerProfile():
    
    SELECT_CURRENTACCOUNT_STMT = """SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '{}';"""            
    SELECT_CUSTOMER_PROFILE_STMT = """SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '{}';"""    
    SELECT_POSITIONKEEPING_STMT = """SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '{}';"""            
    
    session = cluster.connect('customerprofilekeyspace')
    iter = 0;
    i = 1
        
    for i in range(0,repeats): 
        
        partyid = random.choice(partyId_list)
        
        time_inicial = time.time()        
        
        print(SELECT_CUSTOMER_PROFILE_STMT.format(partyid))
        result_cp = session.execute(SELECT_CUSTOMER_PROFILE_STMT.format(partyid))
        print(SELECT_CURRENTACCOUNT_STMT.format(partyid))
        result_ca = session.execute(SELECT_CURRENTACCOUNT_STMT.format(partyid))
        
        for res_cp in result_cp:
            print("RESULTADO CUSTOMER PROFILE", res_cp)
            
        for res_ca in result_ca:
            print("RESULTADO CURRENT ACCOUNT", res_ca)
            print(SELECT_POSITIONKEEPING_STMT.format(res_ca[0]))
            result_pk = session.execute(SELECT_POSITIONKEEPING_STMT.format(res_ca[0]))
            for res_pk in result_pk:
                print("RESULTADO POSITION_KEEPING", res_pk)                        
                time_final = time.time()           
                data_time_collection = round(time_final - time_inicial,3)
                used_cpu = psutil.cpu_percent()
                mem_used = psutil.virtual_memory().percent
                registers.append((iter,data_time_collection,used_cpu,mem_used))
                print((iter,data_time_collection,used_cpu,mem_used))
                iter += 1;
                time_inicial = time.time()
        i = i + 1
        
    return registers

# %%
registers = selectCollectionCustomerProfile()
# Out:
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '555852c2-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '555852c2-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('555852c2-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '4', 'ritchie.amya@example.org', 'Elliott DAmore Jr.', 'Miss', None, 'Mason', '3671', 'sol', '309.422.1999')
# RESULTADO CURRENT ACCOUNT ('471e5f94-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Kub-Halvorson', identification='9.0', schemename='nan'), accountinfo(name='Mills, Aufderhar and Schowalter', identification='nan', schemename='nan'), accountinfo(name='Ward, Shields and Rogahn', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Particular', 'disintermediate virtual infomediaries', datetime.datetime(1988, 6, 30, 14, 38, 32), '555852c2-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1972, 10, 4, 22, 44, 58))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '471e5f94-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('471e5f94-bf6c-11ec-b68e-3bdfc8280f2e', 'IND', 'IND', 0.3955119, 'Ut cumque sint laudantium quis impedit. Qui dolore sit aut ut nulla hi', 6429.5141045, 'Credit', False, 'typed', datetime.datetime(2004, 1, 7, 15, 22, 27), 'Particular')
# (0, 0.016, 49.3, 96.6)
# RESULTADO POSITION_KEEPING ('471e5f94-bf6c-11ec-b68e-3bdfc8280f2e', 'IND', 'USA', 0.0, 'Ut cumque sint laudantium quis impedit. Qui dolore sit aut ut nulla hi', 76659443.98, 'Credit', False, 'typed', datetime.datetime(2019, 3, 22, 17, 0, 18), 'Business')
# (1, 0.0, 0.0, 96.6)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54beb1a8-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54beb1a8-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54beb1a8-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '6', 'llegros@example.org', 'Joseph Tremblay', 'Mr.', None, 'Leo', '7151', 'sol', '05295301214')
# RESULTADO CURRENT ACCOUNT ('4683e25c-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Erdman, Schinner and Quigley', identification='8.0', schemename='UK.OBIE.SortCodeAccountNumber'), accountinfo(name='Schuster, Bayer and Auer', identification='5.0', schemename='UK.business'), accountinfo(name='Kautzer, Rolfson and Kreiger', identification='5.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Business', 'envisioneer collaborative e-markets', datetime.datetime(2005, 8, 13, 3, 46, 35), '54beb1a8-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2015, 11, 9, 4, 9, 58))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4683e25c-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5504292c-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5504292c-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5504292c-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '1', 'zhaley@example.org', 'Freida Swaniawski', 'Prof.', None, 'Quinn', '6031', 'sol', '1-570-084-99')
# RESULTADO CURRENT ACCOUNT ('46c97772-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Hand-Fay', identification='9.0', schemename='nan'), accountinfo(name='Roberts, Walter and Marvin', identification='2.0', schemename='nan')], 'Particular', 'extend intuitive systems', datetime.datetime(2019, 7, 7, 6, 12, 33), '5504292c-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1988, 2, 1, 18, 44, 4))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46c97772-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5508994e-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5508994e-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5508994e-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '8', 'gilberto93@example.net', 'Frida Hamill', 'Mr.', None, 'Pamela', '96', 'sol', '670-999-0041')
# RESULTADO CURRENT ACCOUNT ('46cdd90c-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Jones-Heathcote', identification='nan', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Mayer, Miller and Aufderhar', identification='2.0', schemename='UK.business')], 'Business', 'benchmark best-of-breed webservices', datetime.datetime(1989, 5, 14, 23, 18, 18), '5508994e-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2017, 4, 22, 11, 35, 12))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46cdd90c-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5632e1e4-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5632e1e4-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5632e1e4-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '6', 'tony42@example.com', 'Verdie Pouros', 'Miss', None, 'Belle', '1846', 'pri', '(875)927-568')
# RESULTADO CURRENT ACCOUNT ('47f820e4-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Erdman, Trantow and Towne', identification='5.0', schemename='nan'), accountinfo(name='Kuvalis-Turcotte', identification='4.0', schemename='nan'), accountinfo(name='Grant Inc', identification='9.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Business', 'generate dot-com solutions', datetime.datetime(1987, 10, 2, 16, 15, 11), '5632e1e4-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1974, 10, 16, 1, 28, 36))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47f820e4-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55223fca-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55223fca-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55223fca-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '5', 'gislason.velva@example.org', 'Rosario Kuhic', 'Miss', None, 'Buddy', '698', 'pri', '886-441-6446')
# RESULTADO CURRENT ACCOUNT ('46e81d62-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Nitzsche-Daugherty', identification='2.0', schemename='UK.OBIE.SortCodeAccountNumber'), accountinfo(name='Heaney, Effertz and Rau', identification='7.0', schemename='nan'), accountinfo(name='Jacobson PLC', identification='1.0', schemename='nan'), accountinfo(name='Pacocha, Terry and Will', identification='8.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Business', 'expedite customized ROI', datetime.datetime(2016, 11, 13, 11, 16, 49), '55223fca-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2011, 2, 16, 5, 27, 27))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46e81d62-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('46e81d62-bf6c-11ec-b68e-3bdfc8280f2e', 'EUR', 'GBP', 95.91652406, 'Est quidem repellendus dolor qui. Eos temporibus ea sunt. Pariatur sun', 180766610.5827, 'Debit', False, 'typed', datetime.datetime(1990, 12, 22, 11, 26, 10), 'Particular')
# (2, 0.005, 66.7, 96.6)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55619f62-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55619f62-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55619f62-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '9', 'shaun52@example.com', 'Jaleel Batz', 'Mr.', None, 'Ernest', '3899', 'sol', '033.479.1713')
# RESULTADO CURRENT ACCOUNT ('4727a478-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Wisoky Ltd', identification='6.0', schemename='UK.business'), accountinfo(name='Lueilwitz and Sons', identification='2.0', schemename='nan'), accountinfo(name='Kohler Ltd', identification='8.0', schemename='nan')], 'Particular', 'target plug-and-play action-items', datetime.datetime(1991, 4, 7, 7, 56, 5), '55619f62-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2005, 4, 10, 10, 0, 41))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4727a478-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55af3fd8-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55af3fd8-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55af3fd8-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '9', 'wilma.bergstrom@example.org', 'Wilburn Harber', 'Dr.', None, 'Mozell', '1354', 'sol', '712-808-4789')
# RESULTADO CURRENT ACCOUNT ('47750c2c-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Fay Ltd', identification='5.0', schemename='nan'), accountinfo(name='Cummerata LLC', identification='5.0', schemename='nan')], 'Particular', 'exploit plug-and-play systems', datetime.datetime(1996, 9, 18, 18, 29, 16), '55af3fd8-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1986, 8, 27, 4, 53, 54))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47750c2c-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('47750c2c-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'GBP', 291992.694375, 'Ut necessitatibus in iure cum et sint. Minima ipsa impedit quaerat vel', 3.29391, 'Debit', False, 'typed', datetime.datetime(1979, 12, 31, 6, 35, 54), 'Particular')
# (3, 0.005, 83.3, 96.6)
# RESULTADO POSITION_KEEPING ('47750c2c-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'IND', 8009.3892421, 'Dolores sint vero vero maiores nisi. Et quas illo officiis non ducimus', 369692394.71, 'Debit', False, 'typed', datetime.datetime(2002, 3, 16, 11, 10, 48), 'Particular')
# (4, 0.0, 100.0, 96.6)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5464e34e-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5464e34e-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5464e34e-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '2', 'zwelch@example.com', 'Estell Kirlin', 'Mrs.', None, 'Wilfredo', '8501', 'sol', '1-620-847-01')
# RESULTADO CURRENT ACCOUNT ('462b7d1a-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Ondricka Inc', identification='nan', schemename='UK.business'), accountinfo(name='Becker Ltd', identification='7.0', schemename='nan'), accountinfo(name='Kautzer, Rolfson and Kreiger', identification='5.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Business', 'embrace innovative vortals', datetime.datetime(1982, 12, 25, 16, 19, 16), '5464e34e-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(2004, 3, 27, 18, 39, 57))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '462b7d1a-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54db5c4a-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54db5c4a-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54db5c4a-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '5', 'valentin.buckridge@example.net', 'Mr. Luigi Flatley IV', 'Prof.', None, 'Axel', '8993', 'sol', '1-118-757-03')
# RESULTADO CURRENT ACCOUNT ('46a077f0-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Nolan, Schimmel and Jast', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Nolan, Schimmel and Jast', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Yost, Mills and Shields', identification='1.0', schemename='nan')], 'Business', 'visualize dynamic web-readiness', datetime.datetime(2010, 8, 22, 0, 12, 47), '54db5c4a-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2009, 11, 24, 0, 54, 13))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46a077f0-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('46a077f0-bf6c-11ec-b68e-3bdfc8280f2e', 'IND', 'IND', 0.747896225, 'Est quidem repellendus dolor qui. Eos temporibus ea sunt. Pariatur sun', 85446839.267591, 'Debit', False, 'typed', datetime.datetime(2021, 3, 4, 5, 31), 'Business')
# (5, 0.005, 60.0, 96.6)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5601bc90-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5601bc90-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5601bc90-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '7', 'benedict.carter@example.org', 'Vance Gusikowski', 'Prof.', None, 'Myrtice', '3557', 'pri', '(429)528-591')
# RESULTADO CURRENT ACCOUNT ('47c6cd6e-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Wiza-Turcotte', identification='9.0', schemename='nan'), accountinfo(name='Mosciski, Herzog and Mante', identification='4.0', schemename='UK.business'), accountinfo(name='Walter LLC', identification='1.0', schemename='nan')], 'Particular', 'syndicate virtual technologies', datetime.datetime(1986, 12, 10, 22, 10, 18), '5601bc90-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2007, 4, 1, 23, 56, 17))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47c6cd6e-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54f5477c-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54f5477c-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54f5477c-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '9', 'krystina.dubuque@example.com', 'Janet Conroy', 'Dr.', None, 'Anna', '4429', 'sol', '1-672-213-41')
# RESULTADO CURRENT ACCOUNT ('46ba79a2-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Johns LLC', identification='6.0', schemename='UK.business'), accountinfo(name='Heaney-Crist', identification='7.0', schemename='nan')], 'Business', 'disintermediate virtual niches', datetime.datetime(2002, 10, 16, 6, 53, 32), '54f5477c-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1975, 6, 18, 12, 6, 52))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46ba79a2-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55aaf4f0-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55aaf4f0-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55aaf4f0-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '0', 'gwilkinson@example.org', 'Jettie Franecki', 'Prof.', None, 'Thalia', '9520', 'pri', '1-241-616-54')
# RESULTADO CURRENT ACCOUNT ('4770d058-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Gottlieb, Luettgen and Douglas', identification='2.0', schemename='nan'), accountinfo(name='Borer-Simonis', identification='8.0', schemename='UK.business'), accountinfo(name='Treutel, VonRueden and Zulauf', identification='2.0', schemename='nan')], 'Business', 'reinvent best-of-breed e-markets', datetime.datetime(1979, 5, 18, 23, 36, 53), '55aaf4f0-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1998, 2, 15, 23, 58, 51))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4770d058-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('4770d058-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'IND', 0.0, 'Dolores sint vero vero maiores nisi. Et quas illo officiis non ducimus', 5645.33, 'Credit', False, 'typed', datetime.datetime(1986, 2, 10, 2, 5, 20), 'Business')
# (6, 0.004, 66.7, 96.6)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '56340d62-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '56340d62-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('56340d62-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '8', 'davis.brady@example.com', 'Vickie Klein V', 'Mr.', None, 'Johnson', '4122', 'pri', '1-705-598-18')
# RESULTADO CURRENT ACCOUNT ('47f9d394-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Walter-Wunsch', identification='5.0', schemename='nan'), accountinfo(name='Moen and Sons', identification='4.0', schemename='nan')], 'Particular', 'seize rich users', datetime.datetime(1998, 12, 19, 20, 32, 20), '56340d62-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1974, 8, 3, 17, 55, 49))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47f9d394-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54766b28-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54766b28-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54766b28-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '2', 'katrina.rolfson@example.com', 'General Marvin', 'Prof.', None, 'Yasmin', '2419', 'sol', '+76(8)829365')
# RESULTADO CURRENT ACCOUNT ('463d23d0-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Kreiger Inc', identification='4.0', schemename='nan'), accountinfo(name='Kreiger Inc', identification='4.0', schemename='nan')], 'Business', 'benchmark dynamic convergence', datetime.datetime(1976, 5, 30, 22, 54, 35), '54766b28-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1972, 2, 14, 1, 6, 59))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '463d23d0-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55ccf6b8-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55ccf6b8-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55ccf6b8-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '2', 'noconnell@example.net', 'Dr. Jaron Davis MD', 'Dr.', None, 'Era', '6369', 'sol', '914-259-8503')
# RESULTADO CURRENT ACCOUNT ('47924c9c-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Ernser-Green', identification='nan', schemename='nan'), accountinfo(name='OReilly-Morissette', identification='6.0', schemename='nan'), accountinfo(name='Macejkovic, Tillman and Boyer', identification='2.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Gibson and Sons', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Particular', 'expedite granular relationships', datetime.datetime(1988, 4, 2, 9, 0, 12), '55ccf6b8-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1983, 1, 14, 11, 27, 15))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47924c9c-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54c65caa-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54c65caa-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54c65caa-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '3', 'uwilliamson@example.net', 'Ettie Heathcote', 'Mr.', None, 'Will', '5855', 'pri', '+87(8)745788')
# RESULTADO CURRENT ACCOUNT ('468b5956-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Schoen PLC', identification='4.0', schemename='nan'), accountinfo(name='Herman PLC', identification='2.0', schemename='nan')], 'Particular', 'visualize B2C web-readiness', datetime.datetime(2003, 11, 28, 9, 32, 33), '54c65caa-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(2020, 11, 18, 3, 29, 59))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '468b5956-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('468b5956-bf6c-11ec-b68e-3bdfc8280f2e', 'USA', 'EUR', 223287.482, 'Ut necessitatibus in iure cum et sint. Minima ipsa impedit quaerat vel', 40377.76121100001, 'Credit', False, 'typed', datetime.datetime(1980, 3, 11, 14, 40, 14), 'Particular')
# (7, 0.007, 66.7, 96.6)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5531e0ba-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5531e0ba-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5531e0ba-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '9', 'wilma.bergstrom@example.org', 'Wilburn Harber', 'Dr.', None, 'Mozell', '1354', 'sol', '712-808-4789')
# RESULTADO CURRENT ACCOUNT ('46f7ddba-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Heaney, Effertz and Rau', identification='7.0', schemename='nan'), accountinfo(name='Schulist, Cummings and Grimes', identification='1.0', schemename='nan')], 'Business', 'utilize integrated schemas', datetime.datetime(2006, 6, 4, 22, 31, 36), '5531e0ba-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(2007, 10, 3, 19, 47, 9))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46f7ddba-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('46f7ddba-bf6c-11ec-b68e-3bdfc8280f2e', 'IND', 'EUR', 5718354.436000003, 'Ut necessitatibus in iure cum et sint. Minima ipsa impedit quaerat vel', 0.0, 'Debit', False, 'typed', datetime.datetime(1996, 12, 5, 9, 43, 42), 'Business')
# (8, 0.009, 60.0, 96.6)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5649524e-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5649524e-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5649524e-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '7', 'garry13@example.net', 'Carlie Halvorson', 'Mr.', None, 'Hayley', '9579', 'pri', '488.937.4373')
# RESULTADO CURRENT ACCOUNT ('480f7faa-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Wehner-Lakin', identification='3.0', schemename='UK.OBIE.SortCodeAccountNumber'), accountinfo(name='Kohler Ltd', identification='8.0', schemename='nan'), accountinfo(name='Collins Inc', identification='7.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Particular', 'synthesize proactive metrics', datetime.datetime(2005, 1, 5, 14, 23, 29), '5649524e-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2008, 4, 1, 23, 23, 42))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '480f7faa-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5437cec2-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5437cec2-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5437cec2-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '9', 'bflatley@example.net', 'Miss Mary Dach PhD', 'Prof.', None, 'Wilhelmine', '1150', 'pri', '041-868-0832')
# RESULTADO CURRENT ACCOUNT ('45fbc188-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Orn Ltd', identification='nan', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Wiza-Turcotte', identification='9.0', schemename='nan'), accountinfo(name='Dicki, Strosin and Lind', identification='7.0', schemename='nan'), accountinfo(name='Kuphal, Nienow and Pouros', identification='7.0', schemename='nan')], 'Particular', 'target viral e-tailers', datetime.datetime(1980, 11, 22, 11, 25, 58), '5437cec2-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2020, 10, 27, 3, 13, 22))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '45fbc188-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '56141ce6-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '56141ce6-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('56141ce6-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '3', 'uwilliamson@example.net', 'Ettie Heathcote', 'Mr.', None, 'Will', '5855', 'pri', '+87(8)745788')
# RESULTADO CURRENT ACCOUNT ('47d962bc-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Mosciski, Herzog and Mante', identification='4.0', schemename='UK.business'), accountinfo(name='Lubowitz-Barton', identification='1.0', schemename='nan')], 'Particular', 'productize robust infrastructures', datetime.datetime(1982, 3, 10, 20, 43, 14), '56141ce6-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2013, 4, 27, 3, 42, 14))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47d962bc-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54ac455e-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54ac455e-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54ac455e-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '8', 'davis.brady@example.com', 'Vickie Klein V', 'Mr.', None, 'Johnson', '4122', 'pri', '1-705-598-18')
# RESULTADO CURRENT ACCOUNT ('4671fbaa-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Stroman-Schinner', identification='6.0', schemename='nan'), accountinfo(name='Ortiz-Reichert', identification='8.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Business', 'maximize distributed experiences', datetime.datetime(2019, 1, 2, 12, 9, 10), '54ac455e-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1981, 4, 17, 11, 9, 59))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4671fbaa-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('4671fbaa-bf6c-11ec-b68e-3bdfc8280f2e', 'EUR', 'IND', 513189.663076, 'Est quidem repellendus dolor qui. Eos temporibus ea sunt. Pariatur sun', 0.0, 'Credit', False, 'typed', datetime.datetime(2004, 6, 30, 5, 8, 51), 'Business')
# (9, 0.007, 82.4, 96.7)
# RESULTADO POSITION_KEEPING ('4671fbaa-bf6c-11ec-b68e-3bdfc8280f2e', 'USA', 'GBP', 7.506048599999999, 'Ut cumque sint laudantium quis impedit. Qui dolore sit aut ut nulla hi', 0.0, 'Debit', False, 'typed', datetime.datetime(1989, 11, 7, 11, 35, 39), 'Business')
# (10, 0.0, 0.0, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5534c726-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5534c726-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5534c726-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '8', 'baumbach.aurelia@example.net', 'Dr. Minnie Mante', 'Prof.', None, 'Tabitha', '9400', 'sol', '03378082715')
# RESULTADO CURRENT ACCOUNT ('46fac4c6-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Gleichner and Sons', identification='8.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Lubowitz-Heller', identification='7.0', schemename='nan'), accountinfo(name='Lesch, Schowalter and Effertz', identification='1.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Cummerata LLC', identification='5.0', schemename='nan')], 'Business', 'synergize interactive paradigms', datetime.datetime(1987, 7, 17, 13, 20, 58), '5534c726-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1990, 8, 23, 4, 43, 35))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46fac4c6-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55852e46-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55852e46-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55852e46-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '3', 'hunter34@example.net', 'Dr. Marina Gerhold DVM', 'Ms.', None, 'Monica', '7956', 'sol', '1-616-535-00')
# RESULTADO CURRENT ACCOUNT ('474b1a48-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Douglas PLC', identification='8.0', schemename='UK.business'), accountinfo(name='Jacobson Inc', identification='6.0', schemename='UK.business')], 'Business', 'recontextualize e-business web-readiness', datetime.datetime(2010, 11, 6, 5, 41, 15), '55852e46-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1974, 6, 24, 22, 9, 4))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '474b1a48-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54954e6c-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54954e6c-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54954e6c-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '0', 'garrett46@example.com', 'Genesis Rosenbaum', 'Dr.', None, 'Mae', '2949', 'pri', '(835)640-637')
# RESULTADO CURRENT ACCOUNT ('465ba8a0-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Brekke, Runolfsdottir and Ratke', identification='5.0', schemename='UK.business'), accountinfo(name='Bartoletti, Simonis and OHara', identification='5.0', schemename='nan')], 'Particular', 'incentivize value-added solutions', datetime.datetime(1986, 9, 3, 13, 36, 58), '54954e6c-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1977, 10, 19, 4, 46, 47))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '465ba8a0-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5461c15a-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5461c15a-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5461c15a-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '1', 'darian.johnston@example.net', 'Mr. Santino Wyman DDS', 'Mr.', None, 'Alexandro', '8706', 'pri', '1-975-783-37')
# RESULTADO CURRENT ACCOUNT ('4628596e-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Wehner-Lakin', identification='3.0', schemename='UK.OBIE.SortCodeAccountNumber'), accountinfo(name='Nitzsche-Daugherty', identification='2.0', schemename='UK.OBIE.SortCodeAccountNumber'), accountinfo(name='Schinner, Pacocha and Jacobi', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Lueilwitz PLC', identification='2.0', schemename='UK.business')], 'Business', 'streamline scalable webservices', datetime.datetime(1982, 12, 5, 3, 44, 16), '5461c15a-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2015, 5, 15, 7, 12, 40))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4628596e-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('4628596e-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'USA', 39495594.861999996, 'Dolores sint vero vero maiores nisi. Et quas illo officiis non ducimus', 10.027999999999999, 'Debit', False, 'typed', datetime.datetime(2007, 10, 26, 12, 18, 9), 'Business')
# (11, 0.008, 81.3, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '564c4a8a-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '564c4a8a-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('564c4a8a-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '1', 'yfahey@example.com', 'Ruth Witting II', 'Ms.', None, 'Veda', '4294', 'pri', '1-872-772-47')
# RESULTADO CURRENT ACCOUNT ('48128876-bf6c-11ec-b68e-3bdfc8280f2e', None, 'Particular', 'syndicate frictionless models', datetime.datetime(1972, 5, 20, 13, 42, 54), '564c4a8a-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(2019, 4, 28, 21, 4, 34))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '48128876-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '550379f0-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '550379f0-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('550379f0-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '7', 'layla.gusikowski@example.org', 'Leonardo Dietrich', 'Ms.', None, 'Rosalinda', '7337', 'pri', '288.191.5552')
# RESULTADO CURRENT ACCOUNT ('46c8c714-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Jones, Hagenes and Schulist', identification='nan', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Bahringer PLC', identification='5.0', schemename='nan'), accountinfo(name='Bahringer PLC', identification='5.0', schemename='nan'), accountinfo(name='Gerhold, Stokes and Jacobson', identification='8.0', schemename='nan')], 'Business', 'productize granular e-tailers', datetime.datetime(2015, 1, 17, 12, 59, 17), '550379f0-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1985, 8, 10, 8, 34, 43))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46c8c714-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '559a2d14-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '559a2d14-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('559a2d14-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '7', 'qmorar@example.net', 'Adalberto Mertz', 'Mrs.', None, 'Lonny', '1883', 'pri', '674-992-1868')
# RESULTADO CURRENT ACCOUNT ('47605610-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Gottlieb, Luettgen and Douglas', identification='2.0', schemename='nan'), accountinfo(name='Ernser, Keeling and Gulgowski', identification='2.0', schemename='nan'), accountinfo(name='Conn Inc', identification='3.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Particular', 'engineer mission-critical systems', datetime.datetime(1992, 10, 12, 6, 45, 27), '559a2d14-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1986, 1, 6, 16, 17, 33))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47605610-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55086172-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55086172-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55086172-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '2', 'oreilly@example.net', 'Abigale Funk Jr.', 'Ms.', None, 'Kristin', '3152', 'sol', '345-620-4050')
# RESULTADO CURRENT ACCOUNT ('46cda1bc-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Armstrong Inc', identification='8.0', schemename='nan'), accountinfo(name='Mohr-Zulauf', identification='1.0', schemename='UK.business'), accountinfo(name='Daugherty and Sons', identification='6.0', schemename='UK.business'), accountinfo(name='Bednar, Moore and Hamill', identification='3.0', schemename='UK.business')], 'Particular', 'reinvent turn-key models', datetime.datetime(1998, 8, 27, 12, 45), '55086172-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2001, 8, 15, 21, 57, 4))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46cda1bc-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54432b82-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54432b82-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54432b82-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '5', 'lexus03@example.com', 'Elias Cronin', 'Prof.', None, 'Tamia', '9183', 'pri', '06828617078')
# RESULTADO CURRENT ACCOUNT ('46071790-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Daugherty and Sons', identification='6.0', schemename='UK.business'), accountinfo(name='Pagac Group', identification='4.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Business', 'embrace bricks-and-clicks architectures', datetime.datetime(1981, 5, 16, 2, 7, 20), '54432b82-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2012, 2, 11, 5, 15, 40))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46071790-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('46071790-bf6c-11ec-b68e-3bdfc8280f2e', 'EUR', 'IND', 15619.93294, 'Est quidem repellendus dolor qui. Eos temporibus ea sunt. Pariatur sun', 68.51, 'Debit', False, 'typed', datetime.datetime(1989, 4, 10, 3, 34, 9), 'Particular')
# (12, 0.005, 83.3, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55035e98-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55035e98-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55035e98-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '3', 'hunter34@example.net', 'Dr. Marina Gerhold DVM', 'Ms.', None, 'Monica', '7956', 'sol', '1-616-535-00')
# RESULTADO CURRENT ACCOUNT ('46c8abb2-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Wuckert-Mayer', identification='nan', schemename='nan'), accountinfo(name='Schuster, Bayer and Auer', identification='5.0', schemename='UK.business')], 'Particular', 'reintermediate integrated methodologies', datetime.datetime(1974, 5, 15, 11, 53, 36), '55035e98-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1971, 5, 23, 23, 48, 14))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46c8abb2-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('46c8abb2-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'USA', 391229898.82829, 'Est quidem repellendus dolor qui. Eos temporibus ea sunt. Pariatur sun', 0.8519, 'Credit', False, 'typed', datetime.datetime(1990, 7, 1, 15, 12, 21), 'Business')
# (13, 0.005, 66.7, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5544ca2c-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5544ca2c-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5544ca2c-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '3', 'jerde.ray@example.org', 'Dr. Alberta Armstrong', 'Miss', None, 'Flavio', '6562', 'pri', '(239)323-153')
# RESULTADO CURRENT ACCOUNT ('470af81e-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Schimmel, Hills and Conn', identification='5.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Kuphal, Nienow and Pouros', identification='7.0', schemename='nan')], 'Particular', 'cultivate cross-platform ROI', datetime.datetime(2003, 12, 24, 4, 16, 32), '5544ca2c-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1983, 2, 6, 8, 27, 42))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '470af81e-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55934b98-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55934b98-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55934b98-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '1', 'neil53@example.org', 'Prof. Linnie Harber MD', 'Mr.', None, 'Blanca', '3296', 'sol', '292-598-1225')
# RESULTADO CURRENT ACCOUNT ('475997d0-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Conn Inc', identification='3.0', schemename='UK.OBIE.SortCodeAccountNumber'), accountinfo(name='Quitzon-Bogan', identification='nan', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Bahringer PLC', identification='5.0', schemename='nan')], 'Particular', 'unleash cutting-edge schemas', datetime.datetime(1998, 5, 31, 4, 21, 37), '55934b98-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2015, 12, 7, 14, 13, 59))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '475997d0-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5565e7f2-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5565e7f2-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5565e7f2-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '4', 'felix.olson@example.com', 'Ethelyn Prohaska', 'Ms.', None, 'Cordell', '5376', 'pri', '341.333.9578')
# RESULTADO CURRENT ACCOUNT ('472beb5a-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Kozey-Wuckert', identification='2.0', schemename='nan'), accountinfo(name='OHara PLC', identification='9.0', schemename='UK.business'), accountinfo(name='Stamm Inc', identification='1.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Beer, Fahey and Bode', identification='2.0', schemename='nan')], 'Business', 'synthesize distributed bandwidth', datetime.datetime(2001, 4, 9, 11, 9, 5), '5565e7f2-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1998, 4, 22, 15, 45, 37))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '472beb5a-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '546222c6-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '546222c6-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('546222c6-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '5', 'ruby.abbott@example.org', 'Gabriella Keebler Sr.', 'Prof.', None, 'Jeffry', '9819', 'sol', '+31(3)581121')
# RESULTADO CURRENT ACCOUNT ('4628bb7a-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Lubowitz-Barton', identification='1.0', schemename='nan'), accountinfo(name='Stamm Inc', identification='1.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Johns LLC', identification='6.0', schemename='UK.business')], 'Particular', 'cultivate cross-platform ROI', datetime.datetime(2003, 12, 24, 4, 16, 32), '546222c6-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1983, 2, 6, 8, 27, 42))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4628bb7a-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '551eeb18-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '551eeb18-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('551eeb18-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '0', 'ggreenholt@example.com', 'Meagan Hauck', 'Prof.', None, 'Dorris', '4042', 'sol', '258.845.0766')
# RESULTADO CURRENT ACCOUNT ('46e4a89e-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Douglas and Sons', identification='6.0', schemename='nan'), accountinfo(name='Welch-Russel', identification='6.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Schumm, Hagenes and Gusikowski', identification='1.0', schemename='UK.business'), accountinfo(name='Ruecker-Romaguera', identification='6.0', schemename='nan')], 'Particular', 'reinvent dynamic models', datetime.datetime(2013, 7, 18, 13, 9, 31), '551eeb18-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1989, 11, 4, 23, 49, 29))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46e4a89e-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '545c8e1a-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '545c8e1a-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('545c8e1a-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '6', 'bechtelar.kaelyn@example.org', 'Nikko Cormier', 'Prof.', None, 'Landen', '8347', 'pri', '1-560-408-99')
# RESULTADO CURRENT ACCOUNT ('46233786-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Yost, Mills and Shields', identification='1.0', schemename='nan'), accountinfo(name='Mosciski, Herzog and Mante', identification='4.0', schemename='UK.business'), accountinfo(name='Dicki, Strosin and Lind', identification='7.0', schemename='nan'), accountinfo(name='Kuvalis-Turcotte', identification='4.0', schemename='nan')], 'Particular', 'enhance real-time markets', datetime.datetime(1995, 7, 9, 14, 32, 36), '545c8e1a-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1996, 7, 22, 14, 29, 57))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46233786-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54d388a8-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54d388a8-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54d388a8-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '2', 'lera75@example.net', 'Sam Hahn', 'Mr.', None, 'Eleanore', '2534', 'pri', '684-672-7207')
# RESULTADO CURRENT ACCOUNT ('4698a002-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Murray LLC', identification='3.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Jacobson Inc', identification='6.0', schemename='UK.business'), accountinfo(name='Schamberger-Durgan', identification='5.0', schemename='nan'), accountinfo(name='Reichert Group', identification='2.0', schemename='UK.business')], 'Particular', 'disintermediate global communities', datetime.datetime(2006, 2, 22, 11, 29, 23), '54d388a8-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2008, 9, 22, 21, 25, 34))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4698a002-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('4698a002-bf6c-11ec-b68e-3bdfc8280f2e', 'USA', 'EUR', 5.36, 'Dolores sint vero vero maiores nisi. Et quas illo officiis non ducimus', 4332127.0214817, 'Credit', False, 'typed', datetime.datetime(1988, 8, 20, 21, 24, 50), 'Business')
# (14, 0.008, 82.4, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '551cb5c8-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '551cb5c8-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('551cb5c8-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '9', 'davon.haag@example.org', 'Burnice Heathcote', 'Mrs.', None, 'Mae', '3933', 'pri', '278.065.0353')
# RESULTADO CURRENT ACCOUNT ('46e25f94-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Schinner, Pacocha and Jacobi', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Kulas LLC', identification='5.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Rempel LLC', identification='7.0', schemename='nan'), accountinfo(name='Quigley PLC', identification='2.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Business', 'transition next-generation e-markets', datetime.datetime(2021, 5, 25, 11, 5, 13), '551cb5c8-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1974, 6, 3, 13, 33, 31))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46e25f94-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('46e25f94-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'EUR', 220.47053267, 'Ut cumque sint laudantium quis impedit. Qui dolore sit aut ut nulla hi', 17.697217000000006, 'Debit', False, 'typed', datetime.datetime(1999, 1, 20, 2, 36, 15), 'Business')
# (15, 0.006, 100.0, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '558dceb6-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '558dceb6-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('558dceb6-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '6', 'kwalter@example.net', 'Dwight Murray', 'Dr.', None, 'Elwyn', '9836', 'pri', '(304)208-208')
# RESULTADO CURRENT ACCOUNT ('4753bacc-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Cruickshank, Bruen and Kreiger', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Wuckert-Mayer', identification='nan', schemename='nan')], 'Particular', 'revolutionize turn-key e-markets', datetime.datetime(2015, 1, 3, 3, 54, 19), '558dceb6-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(2014, 4, 19, 14, 50, 57))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4753bacc-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '562338b6-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '562338b6-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('562338b6-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '9', 'rlarson@example.net', 'Arch Johnston', 'Ms.', None, 'Marianna', '9374', 'pri', '+92(6)741251')
# ...
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '461f641c-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('461f641c-bf6c-11ec-b68e-3bdfc8280f2e', 'EUR', 'USA', 21.361829999999998, 'Ut cumque sint laudantium quis impedit. Qui dolore sit aut ut nulla hi', 3.99, 'Debit', False, 'typed', datetime.datetime(2007, 11, 24, 21, 36, 28), 'Particular')
# (31, 0.005, 68.8, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54f8893c-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54f8893c-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54f8893c-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '4', 'gregorio.wunsch@example.org', 'Kristy Runolfsson', 'Dr.', None, 'Freddy', '6298', 'sol', '1-284-383-08')
# RESULTADO CURRENT ACCOUNT ('46bdca12-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Hagenes-Stracke', identification='6.0', schemename='nan'), accountinfo(name='Franecki-Hodkiewicz', identification='nan', schemename='nan')], 'Business', 'syndicate robust niches', datetime.datetime(1991, 6, 23, 8, 39, 47), '54f8893c-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1996, 7, 29, 14, 50, 43))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '46bdca12-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '555e8b88-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '555e8b88-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('555e8b88-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '4', 'aliya.buckridge@example.org', 'Nicholas Mills III', 'Mr.', None, 'Leonora', '8750', 'pri', '(909)458-449')
# RESULTADO CURRENT ACCOUNT ('472498e6-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Lowe Group', identification='9.0', schemename='nan'), accountinfo(name='Bauch-Kutch', identification='8.0', schemename='UK.business')], 'Particular', 'incentivize value-added solutions', datetime.datetime(1986, 9, 3, 13, 36, 58), '555e8b88-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1977, 10, 19, 4, 46, 47))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '472498e6-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '558b93bc-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '558b93bc-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('558b93bc-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '8', 'ludie40@example.com', 'Prof. Kim Beer DVM', 'Mrs.', None, 'Nayeli', '6589', 'sol', '717.870.4485')
# RESULTADO CURRENT ACCOUNT ('4751787a-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Bartoletti, Simonis and OHara', identification='5.0', schemename='nan'), accountinfo(name='Hettinger-Considine', identification='1.0', schemename='UK.business'), accountinfo(name='Cruickshank LLC', identification='1.0', schemename='nan'), accountinfo(name='Stamm Inc', identification='1.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Business', 'generate out-of-the-box markets', datetime.datetime(2019, 10, 20, 4, 14, 1), '558b93bc-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1997, 1, 4, 18, 13, 45))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4751787a-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5558f93e-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5558f93e-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5558f93e-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '2', 'benton42@example.com', 'Miss Matilde Roberts', 'Miss', None, 'Dudley', '9039', 'sol', '(912)901-266')
# RESULTADO CURRENT ACCOUNT ('471f058e-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Rippin Ltd', identification='8.0', schemename='nan'), accountinfo(name='Rempel LLC', identification='7.0', schemename='nan'), accountinfo(name='Kreiger Inc', identification='1.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Particular', 'expedite granular relationships', datetime.datetime(1988, 4, 2, 9, 0, 12), '5558f93e-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1983, 1, 14, 11, 27, 15))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '471f058e-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55be2692-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55be2692-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55be2692-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '4', 'jaydon.mante@example.org', 'Dr. Eleanore Littel MD', 'Dr.', None, 'Alysson', '8237', 'pri', '096-385-9363')
# RESULTADO CURRENT ACCOUNT ('4783bc7c-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='White-Nolan', identification='nan', schemename='nan'), accountinfo(name='Balistreri, Kemmer and Schumm', identification='4.0', schemename='nan')], 'Business', 'harness scalable solutions', datetime.datetime(2008, 7, 7, 8, 9, 32), '55be2692-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1992, 11, 2, 2, 37, 57))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4783bc7c-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5603aa82-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5603aa82-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5603aa82-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '6', 'luigi.schultz@example.net', 'Mrs. Rhea Doyle MD', 'Dr.', None, 'Kevon', '983', 'sol', '910-207-9630')
# RESULTADO CURRENT ACCOUNT ('47c8bc00-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Zieme, Cremin and Aufderhar', identification='2.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Volkman, Mraz and Okuneva', identification='7.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Gibson and Sons', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Business', 'engage strategic platforms', datetime.datetime(2010, 9, 19, 18, 15, 12), '5603aa82-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(2004, 3, 5, 16, 33, 6))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47c8bc00-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '5441ddcc-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '5441ddcc-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('5441ddcc-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '5', 'sierra05@example.net', 'Elwyn Hickle', 'Dr.', None, 'Cristina', '6772', 'pri', '248.228.5340')
# RESULTADO CURRENT ACCOUNT ('4605c1e2-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Kuvalis-Turcotte', identification='4.0', schemename='nan'), accountinfo(name='Gibson and Sons', identification='4.0', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Hand-Fay', identification='9.0', schemename='nan')], 'Particular', 'deliver plug-and-play models', datetime.datetime(2002, 6, 3, 16, 15, 55), '5441ddcc-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(2007, 8, 6, 15, 48, 8))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4605c1e2-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('4605c1e2-bf6c-11ec-b68e-3bdfc8280f2e', 'EUR', 'EUR', 151474.0, 'Ut cumque sint laudantium quis impedit. Qui dolore sit aut ut nulla hi', 0.0, 'Credit', False, 'typed', datetime.datetime(2015, 3, 27, 5, 16, 8), 'Business')
# (32, 0.017, 73.3, 96.7)
# RESULTADO POSITION_KEEPING ('4605c1e2-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'GBP', 0.0, 'Ut cumque sint laudantium quis impedit. Qui dolore sit aut ut nulla hi', 668596607.141, 'Credit', False, 'typed', datetime.datetime(1976, 7, 28, 21, 32, 50), 'Business')
# (33, 0.0, 0.0, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '554cdf82-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '554cdf82-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('554cdf82-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '9', 'russel.beer@example.org', 'Dr. Dameon Crona', 'Mr.', None, 'Vella', '5090', 'sol', '730-039-0751')
# RESULTADO CURRENT ACCOUNT ('4713131e-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Mueller-Zieme', identification='9.0', schemename='nan'), accountinfo(name='Fahey, Pacocha and Von', identification='3.0', schemename='nan'), accountinfo(name='Torp, Swift and Sipes', identification='2.0', schemename='nan'), accountinfo(name='Zieme, Cremin and Aufderhar', identification='2.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Particular', 'productize wireless architectures', datetime.datetime(1996, 1, 20, 6, 40, 46), '554cdf82-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1995, 4, 24, 1, 8, 51))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4713131e-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '54736446-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '54736446-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('54736446-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '8', 'rachael49@example.com', 'Miss Megane Murray MD', 'Prof.', None, 'Rasheed', '5449', 'pri', '+16(1)714434')
# RESULTADO CURRENT ACCOUNT ('463a1794-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Ernser, Keeling and Gulgowski', identification='2.0', schemename='nan'), accountinfo(name='Mohr-Zulauf', identification='1.0', schemename='UK.business'), accountinfo(name='Lueilwitz and Sons', identification='2.0', schemename='nan')], 'Business', 'engage visionary e-commerce', datetime.datetime(2012, 7, 23, 1, 50, 14), '54736446-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1978, 5, 25, 20, 59, 56))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '463a1794-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('463a1794-bf6c-11ec-b68e-3bdfc8280f2e', 'IND', 'EUR', 267740.19951412, 'Est quidem repellendus dolor qui. Eos temporibus ea sunt. Pariatur sun', 76659443.98, 'Credit', False, 'typed', datetime.datetime(1972, 10, 2, 9, 8, 52), 'Particular')
# (34, 0.008, 62.5, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55ce9db0-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55ce9db0-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55ce9db0-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '9', 'nickolas96@example.com', 'Dr. Jess Davis II', 'Prof.', None, 'Tara', '1127', 'sol', '741.089.9284')
# RESULTADO CURRENT ACCOUNT ('4793edcc-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Gerhold LLC', identification='2.0', schemename='UK.business'), accountinfo(name='Baumbach, Hirthe and Goldner', identification='1.0', schemename='ES.OBIE.SortCodeAccountNumber')], 'Particular', 'enable e-business systems', datetime.datetime(2014, 1, 6, 7, 18, 32), '55ce9db0-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1975, 1, 17, 19, 0, 14))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4793edcc-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '562338b6-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '562338b6-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('562338b6-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Principal', None, '9', 'rlarson@example.net', 'Arch Johnston', 'Ms.', None, 'Marianna', '9374', 'pri', '+92(6)741251')
# RESULTADO CURRENT ACCOUNT ('47e5361e-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Quitzon-Bogan', identification='nan', schemename='ES.OBIE.SortCodeAccountNumber'), accountinfo(name='Kozey-Wuckert', identification='2.0', schemename='nan'), accountinfo(name='Balistreri, Kemmer and Schumm', identification='4.0', schemename='nan'), accountinfo(name='Hansen, Ondricka and Rowe', identification='9.0', schemename='nan')], 'Particular', 'seize efficient solutions', datetime.datetime(2001, 12, 21, 0, 38, 27), '562338b6-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1997, 1, 11, 8, 22, 59))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '47e5361e-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55548890-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55548890-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55548890-bf62-11ec-b68e-3bdfc8280f2e', 'US.OBIE.Principal', None, '4', 'baron.bogisich@example.com', 'Ms. Fanny Rippin Jr.', 'Dr.', None, 'Scotty', '6020', 'sol', '(285)666-993')
# RESULTADO CURRENT ACCOUNT ('471aa7be-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Ondricka Inc', identification='nan', schemename='UK.business'), accountinfo(name='Ferry-Oberbrunner', identification='6.0', schemename='nan'), accountinfo(name='Bahringer PLC', identification='5.0', schemename='nan')], 'Particular', 'incubate intuitive channels', datetime.datetime(1980, 5, 30, 4, 58, 45), '55548890-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1987, 3, 19, 23, 54, 3))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '471aa7be-bf6c-11ec-b68e-3bdfc8280f2e';
# RESULTADO POSITION_KEEPING ('471aa7be-bf6c-11ec-b68e-3bdfc8280f2e', 'GBP', 'USA', 477.56, 'Est quidem repellendus dolor qui. Eos temporibus ea sunt. Pariatur sun', 3781.095, 'Debit', False, 'typed', datetime.datetime(2008, 12, 22, 1, 34, 15), 'Business')
# (35, 0.007, 72.7, 96.7)
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '566190e8-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '566190e8-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('566190e8-bf62-11ec-b68e-3bdfc8280f2e', 'UK.OBIE.Secundary', None, '8', 'cdeckow@example.com', 'Cordell Reichel', 'Mr.', None, 'Aiyana', '6690', 'sol', '+64(3)986154')
# RESULTADO CURRENT ACCOUNT ('4827c3e4-bf6c-11ec-b68e-3bdfc8280f2e', None, 'Particular', 'extend visionary communities', datetime.datetime(2011, 6, 24, 2, 52, 13), '566190e8-bf62-11ec-b68e-3bdfc8280f2e', 'Enabled', datetime.datetime(1977, 4, 13, 3, 40, 55))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4827c3e4-bf6c-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM customerprofilekeyspace.customerprofile WHERE partyid = '55af66d4-bf62-11ec-b68e-3bdfc8280f2e';
# SELECT * FROM currentaccountkeyspace.currentaccount WHERE partyid = '55af66d4-bf62-11ec-b68e-3bdfc8280f2e';
# RESULTADO CUSTOMER PROFILE ('55af66d4-bf62-11ec-b68e-3bdfc8280f2e', 'DE.OBIE.Principal', None, '7', 'aglae.ruecker@example.com', 'Adella Renner', 'Miss', None, 'Joyce', '8110', 'pri', '706.320.7637')
# RESULTADO CURRENT ACCOUNT ('4775315c-bf6c-11ec-b68e-3bdfc8280f2e', [accountinfo(name='Ruecker Group', identification='6.0', schemename='UK.business'), accountinfo(name='Franecki-Gleason', identification='nan', schemename='nan'), accountinfo(name='Conroy, Becker and DuBuque', identification='8.0', schemename='nan'), accountinfo(name='Wintheiser and Sons', identification='1.0', schemename='UK.OBIE.SortCodeAccountNumber')], 'Particular', 'envisioneer turn-key deliverables', datetime.datetime(1980, 11, 11, 23, 10, 47), '55af66d4-bf62-11ec-b68e-3bdfc8280f2e', 'Disabled', datetime.datetime(1971, 6, 23, 17, 43, 51))
# SELECT * FROM positionkeepingkeyspace.positionkeeping WHERE accountid = '4775315c-bf6c-11ec-b68e-3bdfc8280f2e';

# %%
#Guardamos los resultados Customer Profile
save_results_to_csv(registers,resultados_etl_select)

# %%
cluster.shutdown()
print('Conexion cerrada')
# Out:
# Conexion cerrada
