# %% [markdown]
# Resultados y graficas TFM Daniel Herranz Segundo

# %%
import pandas as pd
import numpy as np
import json
import os
import matplotlib.pyplot as plt
import psutil
import glob
from sklearn.linear_model import LinearRegression
from scipy import stats
from sklearn import preprocessing
from sklearn.model_selection import KFold
from numerize import numerize
import seaborn as sns

# %%
#Ficheros Cassandra
path = '../Results/Cassandra/'
files = os.listdir(path = path)
files
# Out:
# ['Cassandra_Insert_ConsistencyLevel_QUORUM_CustomerProfile_17042022_14_20_17.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_CustomerProfile_17042022_14_25_01.csv',
#  'Cassandra_Insert_ConsistencyLevel_ANY_CustomerProfile_17042022_14_28_45.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_CustomerProfile_17042022_17_18_52.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_CustomerProfile_17042022_18_17_43.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_CustomerProfile_17042022_21_52_42.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_CustomerProfile_18042022_16_05_39.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_PositionKeeping_18042022_21_14_40.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_PositionKeeping_18042022_22_21_51.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_PositionKeeping_18042022_22_23_02.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_PositionKeeping_18042022_22_24_49.csv',
#  'Cassandra_Insert_ConsistencyLevel_ALL_PositionKeeping_18042022_23_25_41.csv',
# ...

# %%
load_cassandra_quorum = pd.read_csv(path + 'Cassandra_Insert_ConsistencyLevel_QUORUM_CustomerProfile_17042022_14_20_17.csv', index_col=[0])
load_cassandra_all = pd.read_csv(path + 'Cassandra_Insert_ConsistencyLevel_ALL_CustomerProfile_17042022_14_25_01.csv', index_col=[0])
load_cassandra_any = pd.read_csv(path + 'Cassandra_Insert_ConsistencyLevel_ANY_CustomerProfile_17042022_14_28_45.csv', index_col=[0])

# %%
CustomerProfile_data_cas = pd.read_csv(path + 'Cassandra_Insert_ConsistencyLevel_ALL_CustomerProfile_20042022_13_54_29.csv', index_col=[0])

# %%
PositionKeeping_data_cas = pd.read_csv(path + 'Cassandra_Insert_ConsistencyLevel_ALL_PositionKeeping_19042022_02_56_47.csv', index_col=[0])

# %%
cassandra_Select_Test = pd.read_csv(path + 'CassandraSelect_test_19042022_02_47_24.csv')

# %%
cassanda_update_test = pd.read_csv(path + 'CassandraUpdate_test_19042022_15_40_01.csv')

# %%
cassandra_aggregadas_test = pd.read_csv(path + 'CassandraAgregadas_test_19042022_17_02_09.csv')

# %%
cassandra_delete_test = pd.read_csv(path + 'CassandraDelete_test_19042022_17_51_07.csv')

# %%
#Ficheros MongoDB
path = '../Results/MongoDB/'
files = os.listdir(path = path)
files
# Out:
# ['MongoDBUpdate_test_13042022_19_31_15.csv',
#  'MongoDBUpdate_test_13042022_13_31_49.csv',
#  'MongoDBSelect_test_13042022_18_58_45.csv',
#  'MongoDBUpdate_test_13042022_13_24_56.csv',
#  'MongoDBUpdate_test_13042022_00_38_04.csv',
#  'MongoDBUpdate_test_12042022_11_25_51.csv',
#  'MongoDBUpdate_test_12042022_11_02_43.csv',
#  'MongoDBUpdate_test_12042022_10_58_46.csv',
#  'MongoDBUpdate_test_12042022_10_53_00.csv',
#  'MongoDBUpdate_test_11042022_23_57_27.csv',
#  'MongoDBSelect_test_13042022_18_57_58.csv',
#  'MongoDBSelect_test_12042022_16_09_56.csv',
#  'MongoDBSelect_test_12042022_16_02_34.csv',
#  'MongoDBSelect_test_11042022_22_17_25.csv',
#  'MongoDB_Bulk_Insert_3_WC_PositionKeepingCollection_13042022_11_45_42.csv',
#  'MongoDB_Bulk_Insert_3_WC_CustomerProfileCollection_13042022_10_42_16.csv',
#  'MongoDB_Bulk_Insert_3_WC_CurrentAccountCollection_13042022_11_15_04.csv',
#  'MongoDB_Bulk_Insert_3_WC_PositionKeepingCollection_12042022_15_32_56.csv',
# ...

# %%
#'Registros', 'Tiempo', 'CPU','Memoria'
CustomerProfile_data_w3 = pd.read_csv(path + 'MongoDB_Bulk_Insert_3_WC_CustomerProfileCollection_13042022_17_03_36.csv', index_col=[0])
CustomerProfile_data_w2 = pd.read_csv(path + 'MongoDB_Bulk_Insert_2_WC_CustomerProfileCollection_11042022_20_19_30.csv', index_col=[0])
CustomerProfile_data_w1 = pd.read_csv(path + 'MongoDB_Bulk_Insert_1_WC_CustomerProfileCollection_11042022_20_22_29.csv', index_col=[0])

# %%
PositionKeeping_data_w3 = pd.read_csv(path + 'MongoDB_Bulk_Insert_3_WC_PositionKeepingCollection_11042022_21_10_55.csv', index_col=[0])
PositionKeeping_data_w2 = pd.read_csv(path + 'MongoDB_Bulk_Insert_2_WC_PositionKeepingCollection_11042022_20_21_22.csv', index_col=[0])
PositionKeeping_data_w1 = pd.read_csv(path + 'MongoDB_Bulk_Insert_1_WC_PositionKeepingCollection_11042022_20_24_46.csv', index_col=[0])

# %%
MongoDB_Select_Test = pd.read_csv(path + 'MongoDBSelect_test_13042022_18_58_45.csv')

# %%
MongoDB_Update_Test = pd.read_csv(path + 'MongoDBUpdate_test_13042022_13_31_49.csv')

# %%
MongoDB_Aggreg_Test = pd.read_csv(path + 'MongoDBAgregadas_test_13042022_19_55_40.csv')

# %%
MongoDB_Delete_Test = pd.read_csv(path + 'MongoDB_Delete_MultipleCollection_13042022_20_47_45.csv')

# %%
#Ficheros MongoDB
path = '../Results/MySql/'
files = os.listdir(path = path)
files
# Out:
# ['MySQLCurrentAccountSchema_1000_rows_08042022_12_29_32.csv',
#  'MySQLUpdate_test_09042022_20_14_02.csv',
#  'MySQLresultsPositionKeepingSchema_10042022_06_00_54.csv',
#  'MySQLUpdate_test_09042022_20_17_15.csv',
#  'MySQLUpdate_test_09042022_20_23_44.csv',
#  'MySQLUpdate_test_09042022_20_23_51.csv',
#  'MySQLCurrentAccountSchema_10042022_01_23_34.csv',
#  'MySQLCustomerProfileSchema_10042022_00_25_24.csv',
#  'MySQLUpdate_test_10042022_10_50_06.csv',
#  'MySQLUpdate_test_11042022_11_09_09.csv',
#  'MySQLUpdate_test_11042022_11_09_14.csv',
#  'MySQLSelect_test_11042022_12_01_07.csv',
#  'MySQLSelect_test_11042022_12_16_25.csv',
#  'MySQLUpdate_test_11042022_12_17_26.csv',
#  'MySQLUpdate_test_11042022_12_48_12.csv',
#  'MySQLSelect_test_11042022_12_48_20.csv',
#  'MySQLCurrentAccountSchema_11042022_14_21_19.csv',
#  'MySQLSelect_test_11042022_16_58_45.csv',
#  'MySQLFuncionesAgregadas_test_11042022_19_12_42.csv',
#  'MySQLFuncionesAgregadas_test_11042022_19_16_25.csv',
# ...

# %%
CustomerProfile_data_msql = pd.read_csv(path + 'MySQLCurrentAccountSchema_11042022_14_21_19.csv', index_col=[0])
PositionKeeping_data_msql = pd.read_csv(path + 'MySQLresultsPositionKeepingSchema_10042022_06_00_54.csv', index_col=[0])

# %%
MySQL_Select_Test = pd.read_csv(path + 'MySQLUpdate_test_11042022_20_11_29.csv', index_col=[0])

# %%
MySQL_Select = pd.read_csv(path + 'MySQLUpdate_test_11042022_11_09_14.csv', index_col=[0])
len(MySQL_Select)
# Out:
# 4

# %%
MySQL_Delete_Test = pd.read_csv(path + 'MySQLDelete_test_11042022_20_07_28.csv', index_col=[0])

# %%
MySQL_Aggreg_Test = pd.read_csv(path + 'MySQLFuncionesAgregadas_test_11042022_19_20_34.csv', index_col=[0])

# %%
MySQLUpdate_df = pd.read_csv(path + 'MySQLUpdate_test_11042022_20_11_29.csv')
MySQLUpdate_df
# Out:
#     Unnamed: 0  Registros  Tiempo   CPU  Memoria
# 0            0          1   0.970  18.8     51.2
# 1            1          2   0.979  20.4     51.2
# 2            2          3   0.996  21.8     51.2
# 3            3          4   0.970  19.2     51.1
# 4            4          5   0.933  19.4     51.1
# ..         ...        ...     ...   ...      ...
# 95          95         96   0.893  20.9     51.0
# 96          96         97   0.896  24.2     51.0
# 97          97         98   0.899  20.5     51.0
# 98          98         99   0.966  19.7     51.0
# 99          99        100   0.979  19.7     51.0
#
# [100 rows x 5 columns]

# %%
#Comparativa Cassandra replication queries
plt.figure(figsize=(8,6))
# plot a line chart

plt.plot(PositionKeeping_data_cas['Registros'], np.add.accumulate(PositionKeeping_data_cas['Tiempo']),  linewidth=1.0, color = 'r',label='Desnormalizado')
plt.plot(CustomerProfile_data_cas['Registros'], np.add.accumulate(CustomerProfile_data_cas['Tiempo']),  linewidth=1.0, color = 'g',label='one-to-many varias tablas')
plt.xlabel("Documentos")
plt.ylabel("Tiempo (s)")
plt.title("Comparativa Insert Cassandra CustomerProfile (one-to-many) vs Position Keeping (desnormalizado 1 tabla)")
plt.legend(loc='best')
bottom,top = plt.xlim()

plt.show()

# %%
#Comparativa Cassandra replication queries
plt.figure(figsize=(8,6))
# plot a line chart

plt.plot(load_cassandra_quorum['Registros'], np.add.accumulate(load_cassandra_quorum['Tiempo']),  linewidth=1.0, color = 'r',label='Quorum')
plt.plot(load_cassandra_all['Registros'], np.add.accumulate(load_cassandra_all['Tiempo']),  linewidth=1.0, color = 'g',label='All')
plt.plot(load_cassandra_any['Registros'], np.add.accumulate(load_cassandra_any['Tiempo']),  linewidth=1.0, color = 'b',label='Any')
#plt.plot(CustomerProfile_data_msql['Registros'], np.add.accumulate(CustomerProfile_data_msql['Tiempo']),  linewidth=1.0, color = 'y',label='MySQL InnoDB')
plt.xlabel("Documentos")
plt.ylabel("Tiempo (s)")
plt.title("Comparativa replication Cassandra Insert CustomerProfile (one-to-many)")
plt.legend(loc='best')
bottom,top = plt.xlim()

plt.show()

# %%
#Comparativa MongoDB ETL CustomerProfile (one-to-many)
plt.figure(figsize=(8,6))
# plot a line chart

plt.plot(CustomerProfile_data_w3['Registros'].iloc[1:1001], np.add.accumulate(CustomerProfile_data_w3['Tiempo'].iloc[1:1001]),  linewidth=1.0, color = 'r',label='MongoDB wc=3')
plt.plot(CustomerProfile_data_w2['Registros'].iloc[1:1001], np.add.accumulate(CustomerProfile_data_w2['Tiempo'].iloc[1:1001]),  linewidth=1.0, color = 'g',label='MongoDB wc=2')
plt.plot(CustomerProfile_data_w1['Registros'].iloc[1:1001], np.add.accumulate(CustomerProfile_data_w1['Tiempo'].iloc[1:1001]),  linewidth=1.0, color = 'b',label='MongoDB wc=1')
#plt.plot(CustomerProfile_data_msql['Registros'], np.add.accumulate(CustomerProfile_data_msql['Tiempo']),  linewidth=1.0, color = 'y',label='MySQL InnoDB')
plt.xlabel("Documentos")
plt.ylabel("Tiempo (s)")
plt.title("Comparativa WriteConcern 1-3 nodos MongoDB ETL Insert CustomerProfile (one-to-many)")
plt.legend(loc='best')
bottom,top = plt.xlim()

plt.show()

# %%
#Comparativa MongoDB ETL PositionKeeping (one-to-one + one-to-one (saldos debito y credito) + currency)
plt.figure(figsize=(8,6))
# plot a line chart

plt.plot(PositionKeeping_data_w3['Registros'].iloc[1:1001], np.add.accumulate(PositionKeeping_data_w3['Tiempo'].iloc[1:1001]),  linewidth=1.0, color = 'r',label='MongoDB wc=3')
plt.plot(PositionKeeping_data_w2['Registros'].iloc[1:1001], np.add.accumulate(PositionKeeping_data_w2['Tiempo'].iloc[1:1001]),  linewidth=1.0, color = 'g',label='MongoDB wc=2')
plt.plot(PositionKeeping_data_w1['Registros'].iloc[1:1001], np.add.accumulate(PositionKeeping_data_w1['Tiempo'].iloc[1:1001]),  linewidth=1.0, color = 'b',label='MongoDB wc=1')
#plt.plot(PosiitonKeeping_data_msql['Registros'], np.add.accumulate(PosiitonKeeping_data_msql['Tiempo']),  linewidth=1.0, color = 'y',label='MySQL InnoDB')
plt.xlabel("Documentos")
plt.ylabel("Tiempo (s)")
plt.title("Comparativa WriteConcern 1-3 nodos MongoDB ETL Insert one-to-one + one-to-one (saldos debito y credito) + currency")
plt.legend(loc='best')
bottom,top = plt.xlim()

plt.show()

# %%
CustomerProfile_data_msql['Tiempo'].nlargest(n=5)
# Out:
# 765    1.466
# 0      0.336
# 3      0.256
# 412    0.248
# 768    0.243
# Name: Tiempo, dtype: float64

# %%
PositionKeeping_data_msql['Tiempo'].nlargest(n=5)  ### --- NECESARIO PERCENTIL 95% al menos ---- ###
# Out:
# 3    39.700000
# 0    10.000000
# 2     8.300000
# 1     4.188299
# Name: Tiempo, dtype: float64

# %%
#Comparativa tiempos medios ETL Inserccion 1M registros, (one-to-may (Customer Profile))
motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [CustomerProfile_data_w3.Tiempo[CustomerProfile_data_w3.Tiempo < CustomerProfile_data_w3.Tiempo.quantile(.95)].mean(), 
       CustomerProfile_data_msql.Tiempo[CustomerProfile_data_msql.Tiempo < CustomerProfile_data_msql.Tiempo.quantile(.95)].mean(),
       CustomerProfile_data_cas.Tiempo[CustomerProfile_data_cas.Tiempo < CustomerProfile_data_cas.Tiempo.quantile(.95)].mean()]
maximo = [CustomerProfile_data_w3.Tiempo[CustomerProfile_data_w3.Tiempo < CustomerProfile_data_w3.Tiempo.quantile(.95)].max(), 
       CustomerProfile_data_msql.Tiempo[CustomerProfile_data_msql.Tiempo < CustomerProfile_data_msql.Tiempo.quantile(.95)].max(),
         CustomerProfile_data_cas.Tiempo[CustomerProfile_data_cas.Tiempo < CustomerProfile_data_cas.Tiempo.quantile(.95)].max()]
minimo = [CustomerProfile_data_w3.Tiempo[CustomerProfile_data_w3.Tiempo > CustomerProfile_data_w3.Tiempo.quantile(.05)].min(), 
       CustomerProfile_data_msql.Tiempo[CustomerProfile_data_msql.Tiempo > CustomerProfile_data_msql.Tiempo.quantile(.05)].min(),
         CustomerProfile_data_cas.Tiempo[CustomerProfile_data_cas.Tiempo > CustomerProfile_data_cas.Tiempo.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')

# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend()

# Display

#Titulos
plt.ylabel("Tiempo en segundos / 1000 items")
plt.title("ETL MongoDB vs MySQL InnoDB vs Cassandra (Tiempos medios)")
plt.rcParams["figure.figsize"] = (4,4)

plt.show()

#Comparativa tiempos medios ETL Inserccion 1M registros, (one-to-may (Customer Profile))
motores = ['MongoDB', 'MySQL']
avg = [CustomerProfile_data_w3.Tiempo[CustomerProfile_data_w3.Tiempo < CustomerProfile_data_w3.Tiempo.quantile(.95)].mean(), 
       CustomerProfile_data_msql.Tiempo[CustomerProfile_data_msql.Tiempo < CustomerProfile_data_msql.Tiempo.quantile(.95)].mean()]
maximo = [CustomerProfile_data_w3.Tiempo[CustomerProfile_data_w3.Tiempo < CustomerProfile_data_w3.Tiempo.quantile(.95)].max(), 
       CustomerProfile_data_msql.Tiempo[CustomerProfile_data_msql.Tiempo < CustomerProfile_data_msql.Tiempo.quantile(.95)].max()]
minimo = [CustomerProfile_data_w3.Tiempo[CustomerProfile_data_w3.Tiempo > CustomerProfile_data_w3.Tiempo.quantile(.05)].min(), 
       CustomerProfile_data_msql.Tiempo[CustomerProfile_data_msql.Tiempo > CustomerProfile_data_msql.Tiempo.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')

# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend()

# Display

#Titulos
plt.ylabel("Tiempo en segundos / 1000 items")
plt.title("ETL MongoDB vs MySQL InnoDB (Tiempos medios)")
plt.rcParams["figure.figsize"] = (4,4)

plt.show()

# %%
#Comparativa CPU medios,
motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [CustomerProfile_data_w3.CPU[CustomerProfile_data_w3.CPU < CustomerProfile_data_w3.CPU.quantile(.95)].mean(), 
       CustomerProfile_data_msql.CPU[CustomerProfile_data_msql.CPU < CustomerProfile_data_msql.CPU.quantile(.95)].mean(),
      CustomerProfile_data_cas.CPU[CustomerProfile_data_cas.CPU < CustomerProfile_data_cas.CPU.quantile(.95)].mean()]
maximo = [CustomerProfile_data_w3.CPU[CustomerProfile_data_w3.CPU < CustomerProfile_data_w3.CPU.quantile(.95)].max(), 
       CustomerProfile_data_msql.CPU[CustomerProfile_data_msql.CPU < CustomerProfile_data_msql.CPU.quantile(.95)].max(),
         CustomerProfile_data_cas.CPU[CustomerProfile_data_cas.CPU < CustomerProfile_data_cas.CPU.quantile(.95)].max()]
minimo = [CustomerProfile_data_w3.CPU[CustomerProfile_data_w3.CPU > CustomerProfile_data_w3.CPU.quantile(.05)].min(), 
       CustomerProfile_data_msql.CPU[CustomerProfile_data_msql.CPU > CustomerProfile_data_msql.CPU.quantile(.05)].min(),
         CustomerProfile_data_cas.CPU[CustomerProfile_data_cas.CPU > CustomerProfile_data_cas.CPU.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg', color = 'green')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max', color = 'orange')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend()

# Display

#Titulos
plt.ylabel("% CPU en uso / 1000 items")
plt.title("MongoDB vs MySQL InnoDB (CPU)")
plt.rcParams["figure.figsize"] = (4,4)

plt.show()

# %%
#Comparativa Memoria medios,
motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [CustomerProfile_data_w3.Memoria[CustomerProfile_data_w3.Memoria < CustomerProfile_data_w3.Memoria.quantile(.95)].mean(), 
       CustomerProfile_data_msql.Memoria[CustomerProfile_data_msql.Memoria < CustomerProfile_data_msql.Memoria.quantile(.95)].mean(),
      CustomerProfile_data_cas.Memoria[CustomerProfile_data_cas.Memoria < CustomerProfile_data_cas.Memoria.quantile(.95)].mean()]
maximo = [CustomerProfile_data_w3.Memoria[CustomerProfile_data_w3.Memoria < CustomerProfile_data_w3.Memoria.quantile(.95)].max(), 
       CustomerProfile_data_msql.Memoria[CustomerProfile_data_msql.Memoria < CustomerProfile_data_msql.Memoria.quantile(.95)].max(),
         CustomerProfile_data_cas.Memoria[CustomerProfile_data_cas.Memoria < CustomerProfile_data_cas.Memoria.quantile(.95)].max()]
minimo = [CustomerProfile_data_w3.Memoria[CustomerProfile_data_w3.Memoria > CustomerProfile_data_w3.Memoria.quantile(.05)].min(), 
       CustomerProfile_data_msql.Memoria[CustomerProfile_data_msql.Memoria > CustomerProfile_data_msql.Memoria.quantile(.05)].min(),
         CustomerProfile_data_cas.Memoria[CustomerProfile_data_cas.Memoria > CustomerProfile_data_cas.Memoria.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')

# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend()

# Display

#Titulos
plt.ylabel("% Memoria en uso / 1000 items")
plt.title("MongoDB vs MySQL InnoDB (Memoria en uso)")
plt.rcParams["figure.figsize"] = (4,4)

plt.show()

# %%
plt.title("Comparativa tiempo total ETL 1M registros")
plt.autoscale()

plt.plot(CustomerProfile_data_w3['Registros'].iloc[1:1000,], np.add.accumulate(CustomerProfile_data_w3['Tiempo'].iloc[1:1000,]), linewidth=1.0, color = 'r',label='wc=3')
plt.plot(CustomerProfile_data_msql['Registros'].iloc[1:1000,], np.add.accumulate(CustomerProfile_data_msql['Tiempo'].iloc[1:1000,]), linewidth=1.0, color = 'g',label='Mysql')
plt.plot(CustomerProfile_data_cas['Registros'], np.add.accumulate(CustomerProfile_data_cas['Tiempo']), linewidth=1.0, color = 'b',label='Cassandra')
plt.legend(loc='best')
plt.ylabel("Tiempo acumulado (segundos)")
plt.xlabel("Registros")
plt.title("MongoDB vs MySQL InnoDB (Memoria en uso)")
plt.show()

# %%
plt.title("Comparativa CPU en uso ETL 1M registros")
plt.autoscale()
plt.plot(CustomerProfile_data_w3['Registros'].iloc[1:1000,], CustomerProfile_data_w3['CPU'].iloc[1:1000,], linewidth=1.0, color = 'r',label='MongoDB wc=3')
plt.plot(CustomerProfile_data_msql['Registros'].iloc[1:1000,],CustomerProfile_data_msql['CPU'].iloc[1:1000,], linewidth=1.0, color = 'g',label='Mysql')
plt.plot(CustomerProfile_data_cas['Registros'].iloc[1:1000,],CustomerProfile_data_cas['CPU'].iloc[1:1000,], linewidth=1.0, color = 'b',label='Cassandra')
plt.legend(loc='best')
plt.rcParams["figure.figsize"] = (30, 6)
plt.show()

# %%
plt.title("Comparativa Memoria en uso ETL 1M registros")
#plt.figure(figsize=(8,6))
plt.plot(CustomerProfile_data_w3['Registros'].iloc[1:1000,], CustomerProfile_data_w3['Memoria'].iloc[1:1000,], linewidth=1.0, color = 'r',label='MongoDB wc=3')
plt.plot(CustomerProfile_data_msql['Registros'].iloc[1:1000,],CustomerProfile_data_msql['Memoria'].iloc[1:1000,], linewidth=1.0, color = 'g',label='Mysql')
plt.plot(CustomerProfile_data_cas['Registros'].iloc[1:1000,],CustomerProfile_data_cas['Memoria'].iloc[1:1000,], linewidth=1.0, color = 'b',label='Cassandra')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # TEST SELECT

# %%
#Comparativa Select multidominio (3 dominios)

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Tiempo < MongoDB_Select_Test.Tiempo.quantile(.99)].mean(),        
       MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo < MySQL_Select_Test.Tiempo.quantile(.95)].mean(),
       cassandra_Select_Test.Tiempo[cassandra_Select_Test.Tiempo < cassandra_Select_Test.Tiempo.quantile(.95)].mean()]
maximo = [MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Tiempo < MongoDB_Select_Test.Tiempo.quantile(.99)].max(),        
          MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo < MySQL_Select_Test.Tiempo.quantile(.95)].max(),
          cassandra_Select_Test.Tiempo[cassandra_Select_Test.Tiempo < cassandra_Select_Test.Tiempo.quantile(.95)].max()]
#minimo = [MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Memoria > MongoDB_Select_Test.Tiempo.quantile(.05)].min(),        MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo > MySQL_Select_Test.Tiempo.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("Tiempo procesamiento (s)")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (Tiempo select multidominio)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Tiempo < MongoDB_Select_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo < MySQL_Select_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) Cassandra:", round(cassandra_Select_Test.Tiempo[cassandra_Select_Test.Tiempo < cassandra_Select_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Maximo MongoDB:", round(MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Tiempo < MongoDB_Select_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo MySQL InnoDB:", round(MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo < MySQL_Select_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo Cassandra:", round(cassandra_Select_Test.Tiempo[cassandra_Select_Test.Tiempo < cassandra_Select_Test.Tiempo.quantile(.99)].max(),3),'s')
# Out:
# Media (AVG) MongoDB: 0.354 s
# Media (AVG) MySQL InnoDB: 0.904 s
# Media (AVG) Cassandra: 0.004 s
# Maximo MongoDB: 0.362 s
# Maximo MySQL InnoDB: 0.996 s
# Maximo Cassandra: 0.013 s

# %%
#Comparativa Select multidominio (3 dominios)
MySQL_Select_Test

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Select_Test.CPU[MongoDB_Select_Test.CPU < MongoDB_Select_Test.CPU.quantile(.95)].mean(), 
       MySQL_Select_Test.CPU[MySQL_Select_Test.CPU < MySQL_Select_Test.CPU.quantile(.95)].mean(),
      cassandra_Select_Test.CPU[cassandra_Select_Test.CPU < cassandra_Select_Test.CPU.quantile(.95)].mean()]
maximo = [MongoDB_Select_Test.CPU[MongoDB_Select_Test.CPU < MongoDB_Select_Test.CPU.quantile(.95)].max(), 
          MySQL_Select_Test.CPU[MySQL_Select_Test.CPU < MySQL_Select_Test.CPU.quantile(.95)].max(),
         cassandra_Select_Test.CPU[cassandra_Select_Test.CPU < cassandra_Select_Test.CPU.quantile(.95)].max()]
#minimo = [MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Memoria > MongoDB_Select_Test.Tiempo.quantile(.05)].min(),        MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo > MySQL_Select_Test.Tiempo.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg', color = 'green')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max', color = 'orange')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("CPU Usada (%)")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (CPU Select multidominio)")
plt.rcParams["figure.figsize"] = (4,4)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Select_Test.CPU[MongoDB_Select_Test.CPU < MongoDB_Select_Test.CPU.quantile(.95)].mean(),3),'% CPU en uso')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Select_Test.CPU[MongoDB_Select_Test.CPU < MySQL_Select_Test.CPU.quantile(.95)].mean(),3),'% CPU en uso')
print("Media (AVG) Cassandra:", round(cassandra_Select_Test.CPU[cassandra_Select_Test.CPU < cassandra_Select_Test.CPU.quantile(.95)].mean(),3),'% CPU en uso')
print("Maximo MongoDB:", round(MongoDB_Select_Test.CPU[MongoDB_Select_Test.CPU < MongoDB_Select_Test.CPU.quantile(.95)].max(),3),'% CPU en uso')
print("Maximo MySQL InnoDB:", round(MySQL_Select_Test.CPU[MySQL_Select_Test.CPU < MySQL_Select_Test.CPU.quantile(.95)].max(),3),'% CPU en uso')
print("Maximo Cassandra:", round(cassandra_Select_Test.CPU[cassandra_Select_Test.CPU < cassandra_Select_Test.CPU.quantile(.95)].max(),3),'% CPU en uso')
# Out:
# Media (AVG) MongoDB: 34.053 % CPU en uso
# Media (AVG) MySQL InnoDB: 18.8 % CPU en uso
# Media (AVG) Cassandra: 42.116 % CPU en uso
# Maximo MongoDB: 36.4 % CPU en uso
# Maximo MySQL InnoDB: 23.0 % CPU en uso
# Maximo Cassandra: 83.3 % CPU en uso

# %%
#Evolución de la CPU (Picos MongoDB)
plt.title("Comparativa CPU en uso Select 1M registros")
plt.figure(figsize=(8,6))
plt.plot(MongoDB_Select_Test['Registros'], MongoDB_Select_Test['CPU'], linewidth=1.0, color = 'r',label='MongoDB wc=3')
plt.plot(MySQL_Select_Test['Registros'], MySQL_Select_Test['CPU'], linewidth=1.0, color = 'g',label='Mysql')
plt.plot(cassandra_Select_Test['Registros'], cassandra_Select_Test['CPU'], linewidth=1.0, color = 'b',label='Cassandra')
plt.legend(loc='best')
plt.show()

# %%
#Evolución de la CPU (Picos MongoDB)
plt.title("Comparativa Memoria en uso Select 1M registros")
plt.figure(figsize=(8,3))
plt.plot(MongoDB_Select_Test['Registros'], MongoDB_Select_Test['Memoria'], linewidth=1.0, color = 'r',label='MongoDB wc=3')
plt.plot(MySQL_Select_Test['Registros'], MySQL_Select_Test['Memoria'], linewidth=1.0, color = 'g',label='Mysql')
plt.plot(cassandra_Select_Test['Registros'], cassandra_Select_Test['Memoria'], linewidth=1.0, color = 'b',label='Cassandra')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # UPDATE TEST

# %%
#Comparativa Update multidominio

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].mean(),
       MySQLUpdate_df.Tiempo[MySQLUpdate_df.Tiempo < MySQLUpdate_df.Tiempo.quantile(.95)].mean(),
      cassanda_update_test.Tiempo[cassanda_update_test.Tiempo < cassanda_update_test.Tiempo.quantile(.95)].mean()]
maximo = [MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].max(),
          MySQLUpdate_df.Tiempo[MySQLUpdate_df.Tiempo < MySQLUpdate_df.Tiempo.quantile(.95)].max(),
         cassanda_update_test.Tiempo[cassanda_update_test.Tiempo < cassanda_update_test.Tiempo.quantile(.95)].max()]
#minimo = [MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Memoria > MongoDB_Select_Test.Tiempo.quantile(.05)].min(),        MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo > MySQL_Select_Test.Tiempo.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("Tiempo procesamiento (s)")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (Tiempo update masivo +100K registros)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) MySQL InnoDB:", round(MySQLUpdate_df.Tiempo[MySQLUpdate_df.Tiempo < MySQLUpdate_df.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) Cassandra:", round(cassanda_update_test.Tiempo[cassanda_update_test.Tiempo < cassanda_update_test.Tiempo.quantile(.99)].mean(),3),'s')
print("Maximo MongoDB:", round(MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo MySQL InnoDB:", round(MySQLUpdate_df.Tiempo[MySQL_Select_Test.Tiempo < MySQLUpdate_df.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo Cassandra:", round(cassanda_update_test.Tiempo[cassanda_update_test.Tiempo < cassanda_update_test.Tiempo.quantile(.99)].max(),3),'s')
# Out:
# Media (AVG) MongoDB: 1.425 s
# Media (AVG) MySQL InnoDB: 0.904 s
# Media (AVG) Cassandra: 139.236 s
# Maximo MongoDB: 1.468 s
# Maximo MySQL InnoDB: 0.996 s
# Maximo Cassandra: 209.964 s

# %%
#Zoom MongoDB vs MySQL (Descartamos Cassandra)
#Comparativa Update multidominio

motores = ['MongoDB', 'MySQL']
avg = [MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].mean(),
       MySQLUpdate_df.Tiempo[MySQLUpdate_df.Tiempo < MySQLUpdate_df.Tiempo.quantile(.95)].mean()]
maximo = [MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].max(),
          MySQLUpdate_df.Tiempo[MySQLUpdate_df.Tiempo < MySQLUpdate_df.Tiempo.quantile(.95)].max()]


x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("Tiempo procesamiento (s)")
plt.title("MongoDB vs MySQL InnoDB (Tiempo update masivo +100K registros)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) MySQL InnoDB:", round(MySQLUpdate_df.Tiempo[MySQLUpdate_df.Tiempo < MySQLUpdate_df.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) Cassandra:", round(cassanda_update_test.Tiempo[cassanda_update_test.Tiempo < cassanda_update_test.Tiempo.quantile(.99)].mean(),3),'s')
print("Maximo MongoDB:", round(MongoDB_Update_Test.Tiempo[MongoDB_Update_Test.Tiempo < MongoDB_Update_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo MySQL InnoDB:", round(MySQLUpdate_df.Tiempo[MySQL_Select_Test.Tiempo < MySQLUpdate_df.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo Cassandra:", round(cassanda_update_test.Tiempo[cassanda_update_test.Tiempo < cassanda_update_test.Tiempo.quantile(.99)].max(),3),'s')
# Out:
# Media (AVG) MongoDB: 1.425 s
# Media (AVG) MySQL InnoDB: 0.904 s
# Media (AVG) Cassandra: 139.236 s
# Maximo MongoDB: 1.468 s
# Maximo MySQL InnoDB: 0.996 s
# Maximo Cassandra: 209.964 s

# %%
#Comparativa Update multidominio

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Update_Test.CPU[MongoDB_Update_Test.CPU < MongoDB_Update_Test.CPU.quantile(.99)].mean(),
       MySQLUpdate_df.CPU[MySQLUpdate_df.CPU < MySQLUpdate_df.CPU.quantile(.95)].mean(),
      cassanda_update_test.CPU[cassanda_update_test.CPU < cassanda_update_test.CPU.quantile(.95)].mean()]

maximo = [MongoDB_Update_Test.CPU[MongoDB_Update_Test.CPU < MongoDB_Update_Test.CPU.quantile(.99)].max(),
          MySQLUpdate_df.CPU[MySQLUpdate_df.CPU < MySQLUpdate_df.CPU.quantile(.95)].max(),                 
         cassanda_update_test.CPU[cassanda_update_test.CPU < cassanda_update_test.CPU.quantile(.95)].max()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg', color = 'green')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max', color = 'orange')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("CPU en uso (%)")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (CPU update masivo +100K registros)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Update_Test.CPU[MongoDB_Select_Test.CPU < MongoDB_Update_Test.CPU.quantile(.99)].mean(),3),'%')
print("Media (AVG) MySQL InnoDB:", round(MySQLUpdate_df.CPU[MySQLUpdate_df.CPU < MySQLUpdate_df.CPU.quantile(.99)].mean(),3),'%')
print("Media (AVG) Cassandra:", round(cassanda_update_test.CPU[cassanda_update_test.CPU < cassanda_update_test.CPU.quantile(.99)].mean(),3),'%')
print("Maximo MongoDB:", round(MongoDB_Update_Test.CPU[MongoDB_Update_Test.CPU < MongoDB_Update_Test.CPU.quantile(.99)].max(),3),'%')
print("Maximo MySQL InnoDB:", round(MySQLUpdate_df.CPU[MySQL_Select_Test.CPU < MySQLUpdate_df.CPU.quantile(.99)].max(),3),'%')
print("Maximo Cassandra:", round(cassanda_update_test.CPU[cassanda_update_test.CPU < cassanda_update_test.CPU.quantile(.99)].max(),3),'%')
# Out:
# Media (AVG) MongoDB: 20.437 %
# Media (AVG) MySQL InnoDB: 20.001 %
# Media (AVG) Cassandra: 32.744 %
# Maximo MongoDB: 38.4 %
# Maximo MySQL InnoDB: 25.7 %
# Maximo Cassandra: 37.0 %

# %%
#Comparativa Update multidominio
motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Update_Test.Memoria[MongoDB_Update_Test.Memoria < MongoDB_Update_Test.Memoria.quantile(.99)].mean(),
       MySQLUpdate_df.Memoria[MySQLUpdate_df.Memoria < MySQLUpdate_df.Memoria.quantile(.95)].mean(),
      cassanda_update_test.Memoria[cassanda_update_test.Memoria < cassanda_update_test.Memoria.quantile(.95)].mean()]
maximo = [MongoDB_Update_Test.Memoria[MongoDB_Update_Test.Memoria < MongoDB_Update_Test.Memoria.quantile(.99)].max(),
          MySQLUpdate_df.Memoria[MySQLUpdate_df.Memoria < MySQLUpdate_df.Memoria.quantile(.95)].max(),
         cassanda_update_test.Memoria[cassanda_update_test.Memoria < cassanda_update_test.Memoria.quantile(.95)].max()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("Memoria en uso (%) ")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (Memoria update masivo +100K registros)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Update_Test.Memoria[MongoDB_Select_Test.Memoria < MongoDB_Update_Test.Memoria.quantile(.99)].mean(),3),'%')
print("Media (AVG) MySQL InnoDB:", round(MySQLUpdate_df.Memoria[MySQLUpdate_df.Memoria < MySQLUpdate_df.Memoria.quantile(.99)].mean(),3),'%')
print("Media (AVG) Cassandra:", round(cassanda_update_test.Memoria[cassanda_update_test.Memoria < cassanda_update_test.Memoria.quantile(.99)].mean(),3),'%')
print("Maximo MongoDB:", round(MongoDB_Update_Test.Memoria[MongoDB_Update_Test.Memoria < MongoDB_Update_Test.Memoria.quantile(.99)].max(),3),'%')
print("Maximo MySQL InnoDB:", round(MySQLUpdate_df.Memoria[MySQL_Select_Test.Memoria < MySQLUpdate_df.Memoria.quantile(.99)].max(),3),'%')
print("Maximo Cassandra:", round(cassanda_update_test.Memoria[cassanda_update_test.Memoria < cassanda_update_test.Memoria.quantile(.99)].max(),3),'%')
# Out:
# Media (AVG) MongoDB: nan %
# Media (AVG) MySQL InnoDB: 51.082 %
# Media (AVG) Cassandra: 91.189 %
# Maximo MongoDB: 58.5 %
# Maximo MySQL InnoDB: 51.2 %
# Maximo Cassandra: 92.1 %

# %% [markdown]
# # FUNCIONES AGREGADAS (MAX, MIN y AVG)

# %%
#Comparativa funciones agregadas multidominio

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Aggreg_Test.Tiempo[MongoDB_Aggreg_Test.Tiempo < MongoDB_Aggreg_Test.Tiempo.quantile(.99)].mean(),
       MySQL_Aggreg_Test.Tiempo[MySQL_Aggreg_Test.Tiempo < MySQL_Aggreg_Test.Tiempo.quantile(.95)].mean(),
      cassandra_aggregadas_test.Tiempo[cassandra_aggregadas_test.Tiempo < cassandra_aggregadas_test.Tiempo.quantile(.95)].mean()]
maximo = [MongoDB_Aggreg_Test.Tiempo[MongoDB_Aggreg_Test.Tiempo < MongoDB_Aggreg_Test.Tiempo.quantile(.99)].max(),
          MySQL_Aggreg_Test.Tiempo[MySQL_Aggreg_Test.Tiempo < MySQL_Aggreg_Test.Tiempo.quantile(.95)].max(),
         cassandra_aggregadas_test.Tiempo[cassandra_aggregadas_test.Tiempo < cassandra_aggregadas_test.Tiempo.quantile(.95)].max()]
#minimo = [MongoDB_Select_Test.Tiempo[MongoDB_Select_Test.Memoria > MongoDB_Select_Test.Tiempo.quantile(.05)].min(),        MySQL_Select_Test.Tiempo[MySQL_Select_Test.Tiempo > MySQL_Select_Test.Tiempo.quantile(.05)].min()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("Tiempo procesamiento (s) calculo")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (Tiempo calculo max,min,avg multidominio)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Aggreg_Test.Tiempo[MongoDB_Aggreg_Test.Tiempo < MongoDB_Aggreg_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Aggreg_Test.Tiempo[MySQL_Aggreg_Test.Tiempo < MySQL_Aggreg_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) Cassandra:", round(cassandra_aggregadas_test.Tiempo[cassandra_aggregadas_test.Tiempo < cassandra_aggregadas_test.Tiempo.quantile(.99)].mean(),3),'s')
print("Maximo MongoDB:", round(MongoDB_Aggreg_Test.Tiempo[MongoDB_Aggreg_Test.Tiempo < MongoDB_Aggreg_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo MySQL InnoDB:", round(MySQL_Aggreg_Test.Tiempo[MySQL_Aggreg_Test.Tiempo < MySQL_Aggreg_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo MySQL Cassandra:", round(cassandra_aggregadas_test.Tiempo[cassandra_aggregadas_test.Tiempo < cassandra_aggregadas_test.Tiempo.quantile(.99)].max(),3),'s')
# Out:
# Media (AVG) MongoDB: 11.899 s
# Media (AVG) MySQL InnoDB: 0.613 s
# Media (AVG) Cassandra: 50.899 s
# Maximo MongoDB: 11.971 s
# Maximo MySQL InnoDB: 0.65 s
# Maximo MySQL Cassandra: 56.822 s

# %%
#Comparativa Aggregación multidominio CPU

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Aggreg_Test.CPU[MongoDB_Aggreg_Test.CPU < MongoDB_Aggreg_Test.CPU.quantile(.99)].mean(),
       MySQL_Aggreg_Test.CPU[MySQL_Aggreg_Test.CPU < MySQL_Aggreg_Test.CPU.quantile(.95)].mean(),
      cassandra_aggregadas_test.CPU[cassandra_aggregadas_test.CPU < cassandra_aggregadas_test.CPU.quantile(.95)].mean()]
maximo = [MongoDB_Aggreg_Test.CPU[MongoDB_Aggreg_Test.CPU < MongoDB_Aggreg_Test.CPU.quantile(.99)].max(),
          MySQL_Aggreg_Test.CPU[MySQL_Aggreg_Test.CPU < MySQL_Aggreg_Test.CPU.quantile(.95)].max(),
         cassandra_aggregadas_test.CPU[cassandra_aggregadas_test.CPU < cassandra_aggregadas_test.CPU.quantile(.95)].max()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("CPU en uso (%)")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (Tiempo calculo max,min y avg multidominio)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Aggreg_Test.CPU[MongoDB_Aggreg_Test.CPU < MongoDB_Aggreg_Test.CPU.quantile(.99)].mean(),3),'s')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Aggreg_Test.CPU[MySQL_Aggreg_Test.CPU < MySQL_Aggreg_Test.CPU.quantile(.99)].mean(),3),'s')
print("Media (AVG) Cassandra:", round(cassandra_aggregadas_test.CPU[cassandra_aggregadas_test.CPU < cassandra_aggregadas_test.CPU.quantile(.99)].mean(),3),'s')
print("Maximo MongoDB:", round(MongoDB_Aggreg_Test.CPU[MongoDB_Aggreg_Test.CPU < MongoDB_Aggreg_Test.CPU.quantile(.99)].max(),3),'s')
print("Maximo MySQL InnoDB:", round(MySQL_Aggreg_Test.CPU[MySQL_Select_Test.CPU < MySQL_Aggreg_Test.CPU.quantile(.99)].max(),3),'s')
print("Maximo Cassandra:", round(cassandra_aggregadas_test.CPU[cassandra_aggregadas_test.CPU < cassandra_aggregadas_test.CPU.quantile(.99)].max(),3),'s')
# Out:
# Media (AVG) MongoDB: 43.4 s
# Media (AVG) MySQL InnoDB: 19.176 s
# Media (AVG) Cassandra: 26.1 s
# Maximo MongoDB: 52.1 s
# Maximo MySQL InnoDB: 32.5 s
# Maximo Cassandra: 29.3 s

# %%
#Comparativa Aggregación multidominio CPU

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Aggreg_Test.Memoria[MongoDB_Aggreg_Test.Memoria < MongoDB_Aggreg_Test.Memoria.quantile(.99)].mean(),
       MySQL_Aggreg_Test.Memoria[MySQL_Aggreg_Test.Memoria < MySQL_Aggreg_Test.Memoria.quantile(.95)].mean(),
      cassandra_aggregadas_test.Memoria[cassandra_aggregadas_test.Memoria < cassandra_aggregadas_test.Memoria.quantile(.95)].mean()]
maximo = [MongoDB_Aggreg_Test.Memoria[MongoDB_Aggreg_Test.Memoria < MongoDB_Aggreg_Test.Memoria.quantile(.99)].max(),
          MySQL_Aggreg_Test.Memoria[MySQL_Aggreg_Test.Memoria < MySQL_Aggreg_Test.Memoria.quantile(.95)].max(),
         cassandra_aggregadas_test.Memoria[cassandra_aggregadas_test.Memoria < cassandra_aggregadas_test.Memoria.quantile(.95)].max()]


x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg', color = 'green')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max', color = 'orange')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("Memoria en uso (%)")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra(Memoria en uso calculo max,min y avg multidominio)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Aggreg_Test.Memoria[MongoDB_Aggreg_Test.Memoria < MongoDB_Aggreg_Test.Memoria.quantile(.99)].mean(),3),'s')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Aggreg_Test.Memoria[MySQL_Aggreg_Test.Memoria < MySQL_Aggreg_Test.Memoria.quantile(.99)].mean(),3),'s')
print("Media (AVG) Cassandra:", round(cassandra_aggregadas_test.Memoria[cassandra_aggregadas_test.Memoria < cassandra_aggregadas_test.Memoria.quantile(.99)].mean(),3),'s')
print("Maximo MongoDB:", round(MongoDB_Aggreg_Test.Memoria[MongoDB_Aggreg_Test.Memoria < MongoDB_Aggreg_Test.Memoria.quantile(.99)].max(),3),'s')
print("Maximo MySQL InnoDB:", round(MySQL_Aggreg_Test.Memoria[MySQL_Aggreg_Test.Memoria < MySQL_Aggreg_Test.Memoria.quantile(.99)].max(),3),'s')
print("Maximo Cassandra:", round(cassandra_aggregadas_test.Memoria[cassandra_aggregadas_test.Memoria < cassandra_aggregadas_test.Memoria.quantile(.99)].max(),3),'s')
# Out:
# Media (AVG) MongoDB: 69.678 s
# Media (AVG) MySQL InnoDB: 49.2 s
# Media (AVG) Cassandra: 91.714 s
# Maximo MongoDB: 69.9 s
# Maximo MySQL InnoDB: 49.2 s
# Maximo Cassandra: 91.9 s

# %% [markdown]
# # BORRADO TEST

# %%
#Comparativa borrado en cascada multidominio

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Delete_Test.Tiempo[MongoDB_Delete_Test.Tiempo < MongoDB_Delete_Test.Tiempo.quantile(.99)].mean(),
       MySQL_Delete_Test.Tiempo[MySQL_Delete_Test.Tiempo < MySQL_Delete_Test.Tiempo.quantile(.95)].mean(),
      cassandra_delete_test.Tiempo[cassandra_delete_test.Tiempo < cassandra_delete_test.Tiempo.quantile(.95)].mean()]
maximo = [MongoDB_Delete_Test.Tiempo[MongoDB_Delete_Test.Tiempo < MongoDB_Delete_Test.Tiempo.quantile(.99)].max(),
          MySQL_Delete_Test.Tiempo[MySQL_Delete_Test.Tiempo < MySQL_Delete_Test.Tiempo.quantile(.95)].max(),
         cassandra_delete_test.Tiempo[cassandra_delete_test.Tiempo < cassandra_delete_test.Tiempo.quantile(.95)].max()]


x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("Tiempo procesamiento (s) borrado registro multidominio")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (Tiempo calculo borrado cascada multidominio)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Delete_Test.Tiempo[MongoDB_Delete_Test.Tiempo < MongoDB_Delete_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Delete_Test.Tiempo[MySQL_Delete_Test.Tiempo < MySQL_Delete_Test.Tiempo.quantile(.99)].mean(),3),'s')
print("Media (AVG) Cassandra:", round(cassandra_delete_test.Tiempo[cassandra_delete_test.Tiempo < cassandra_delete_test.Tiempo.quantile(.99)].mean(),3),'s')
print("Maximo MongoDB:", round(MongoDB_Delete_Test.Tiempo[MongoDB_Delete_Test.Tiempo < MongoDB_Delete_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo MySQL InnoDB:", round(MySQL_Delete_Test.Tiempo[MySQL_Delete_Test.Tiempo < MySQL_Delete_Test.Tiempo.quantile(.99)].max(),3),'s')
print("Maximo Cassandra:", round(cassandra_delete_test.Tiempo[cassandra_delete_test.Tiempo < cassandra_delete_test.Tiempo.quantile(.99)].max(),3),'s')
# Out:
# Media (AVG) MongoDB: 0.363 s
# Media (AVG) MySQL InnoDB: 0.345 s
# Media (AVG) Cassandra: 0.005 s
# Maximo MongoDB: 0.382 s
# Maximo MySQL InnoDB: 0.361 s
# Maximo Cassandra: 0.014 s

# %%
#Comparativa borrado en cascada multidominio

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Delete_Test.CPU[MongoDB_Delete_Test.CPU < MongoDB_Delete_Test.CPU.quantile(.99)].mean(),
       MySQL_Delete_Test.CPU[MySQL_Delete_Test.CPU < MySQL_Delete_Test.CPU.quantile(.95)].mean(),
      cassandra_delete_test.CPU[cassandra_delete_test.CPU < cassandra_delete_test.CPU.quantile(.95)].mean()]
maximo = [MongoDB_Delete_Test.CPU[MongoDB_Delete_Test.CPU < MongoDB_Delete_Test.CPU.quantile(.99)].max(),
          MySQL_Delete_Test.CPU[MySQL_Delete_Test.CPU < MySQL_Delete_Test.CPU.quantile(.95)].max(),
         cassandra_delete_test.CPU[cassandra_delete_test.CPU < cassandra_delete_test.CPU.quantile(.95)].max()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg', color = 'green')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max', color = 'orange')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("%CPU en uso borrado registro multidominio")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (CPU en uso borrado cascada multidominio)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Delete_Test.CPU[MongoDB_Delete_Test.CPU < MongoDB_Delete_Test.CPU.quantile(.99)].mean(),3),'%')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Delete_Test.CPU[MySQL_Delete_Test.CPU < MySQL_Delete_Test.CPU.quantile(.99)].mean(),3),'%')
print("Media (AVG) Cassandra:", round(cassandra_delete_test.CPU[cassandra_delete_test.CPU < cassandra_delete_test.CPU.quantile(.99)].mean(),3),'%')
print("Maximo MongoDB:", round(MongoDB_Delete_Test.CPU[MongoDB_Delete_Test.CPU < MongoDB_Delete_Test.CPU.quantile(.99)].max(),3),'%')
print("Maximo MySQL InnoDB:", round(MySQL_Delete_Test.CPU[MySQL_Delete_Test.CPU < MySQL_Delete_Test.CPU.quantile(.99)].max(),3),'%')
print("Maximo Cassandra:", round(cassandra_delete_test.CPU[cassandra_delete_test.CPU < cassandra_delete_test.CPU.quantile(.99)].max(),3),'%')
# Out:
# Media (AVG) MongoDB: 17.69 %
# Media (AVG) MySQL InnoDB: 21.143 %
# Media (AVG) Cassandra: 55.626 %
# Maximo MongoDB: 25.3 %
# Maximo MySQL InnoDB: 29.0 %
# Maximo Cassandra: 83.3 %

# %%
#Comparativa borrado en cascada multidominio

motores = ['MongoDB', 'MySQL', 'Cassandra']
avg = [MongoDB_Delete_Test.Memoria[MongoDB_Delete_Test.Memoria < MongoDB_Delete_Test.Memoria.quantile(.99)].mean(),
       MySQL_Delete_Test.Memoria[MySQL_Delete_Test.Memoria < MySQL_Delete_Test.Memoria.quantile(.95)].mean(),
      cassandra_delete_test.Memoria[cassandra_delete_test.Memoria < cassandra_delete_test.Memoria.quantile(.95)].mean()]
maximo = [MongoDB_Delete_Test.Memoria[MongoDB_Delete_Test.Memoria < MongoDB_Delete_Test.Memoria.quantile(.99)].max(),
          MySQL_Delete_Test.Memoria[MySQL_Delete_Test.Memoria < MySQL_Delete_Test.Memoria.quantile(.95)].max(),
         cassandra_delete_test.Memoria[cassandra_delete_test.Memoria < cassandra_delete_test.Memoria.quantile(.95)].max()]

x_axis = np.arange(len(motores))

# Multi bar Chart

plt.bar(x_axis -0.2, avg, width=0.4, label = 'Avg', color = 'green')
plt.bar(x_axis +0.2, maximo, width=0.4, label = 'Max', color = 'orange')
#plt.bar(x_axis -0.2, minimo, width=0.4, label = 'Min')


# Xticks

plt.xticks(x_axis, motores)

# Add legend

plt.legend(loc='best')

# Display

#Titulos
plt.ylabel("%Memoria en uso borrado registro multidominio")
plt.title("MongoDB vs MySQL InnoDB vs Cassandra (Memoria en uso borrado cascada multidominio)")
plt.rcParams["figure.figsize"] = (4,6)

plt.show()

print("Media (AVG) MongoDB:", round(MongoDB_Delete_Test.Memoria[MongoDB_Delete_Test.Memoria < MongoDB_Delete_Test.Memoria.quantile(.99)].mean(),3),'%')
print("Media (AVG) MySQL InnoDB:", round(MySQL_Delete_Test.Memoria[MySQL_Delete_Test.Memoria < MySQL_Delete_Test.Memoria.quantile(.99)].mean(),3),'%')
print("Maximo MongoDB:", round(MongoDB_Delete_Test.Memoria[MongoDB_Delete_Test.Memoria < MongoDB_Delete_Test.Memoria.quantile(.99)].max(),3),'%')
print("Maximo MySQL InnoDB:", round(MySQL_Delete_Test.Memoria[MySQL_Delete_Test.Memoria < MySQL_Delete_Test.Memoria.quantile(.99)].max(),3),'%')
# Out:
# Media (AVG) MongoDB: nan %
# Media (AVG) MySQL InnoDB: nan %
# Maximo MongoDB: nan %
# Maximo MySQL InnoDB: nan %
